# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/tools_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/tools_numpy.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso:  ]()

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = ''>

# %% [markdown]
# Reconocimiento a las profesoras destacadas en enseñanza de la matemática en Colombia

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde el archivo CSV
path = 'C:/Users/marco/Documentos/docencia/groups_list/infantil.xlsx'
estudiantes = pd.read_excel(path)
estudiantes.index = range(1, len(estudiantes) + 1)
estudiantes.head(17)

# %%
# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def asistencia():
    global lista_estudiantes
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Asistió {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        # Validación de entrada
        if asistencia == 's':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Parcial'] += 0.3
            print(f"Actualizado: {estudiante_aleatorio} ahora tiene {estudiantes.at[indice, 'Parcial']} en la columna 'Parcial'.")
        
        elif asistencia != 'n':
            print("Entrada inválida. Por favor, introduce 's' para sí o 'n' para no.")
            return  # Volver a preguntar para el mismo estudiante si la entrada es inválida
        
        # Remover al estudiante de la lista para no llamarlo de nuevo
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Función para guardar cambios al final de la sesión
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
while lista_estudiantes:
    asistencia()

# Guardar los cambios una vez que todos los estudiantes hayan sido llamados
guardar_cambios()
# Out:
# Llamando a ROSILLO TEJADA VANESA...
# Cambios guardados en el archivo CSV.
# Llamando a QUINONEZ CERVANTES MARIANA...

# %% [markdown]
# # Principios de mi labor docente

# %% [markdown]
# ## Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# <img src = 'https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png' width = 200>

# %% [markdown]
# # Metodología de enseñanza basada en problemas (ABP)

# %% [markdown]
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg' width = 200>

# %% [markdown]
# # Desarrollo del pensamiento computacional con Lenguaje R y con archivos R Markdown orientado a la formación en ciencia de datos

# %% [markdown]
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg' width = 200>

# %% [markdown]
# # Principio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto

# %% [markdown]
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1' width = 200>

# %% [markdown]
# El enfoque STEAMS en educación preescolar, primaria y secundaria es una extensión del enfoque STEM (Ciencia, Tecnología, Ingeniería y Matemáticas) y su variante STEAM, que incorpora el Arte.

# %% [markdown]
# El acrónimo STEAMS incluye:

# %% [markdown]
# 1. **Science (Ciencia):** Fomenta la curiosidad por el mundo natural y el desarrollo de habilidades científicas, como la observación, experimentación y análisis.

# %% [markdown]
# 2. **Technology (Tecnología):** Integra herramientas tecnológicas para potenciar el aprendizaje y la resolución de problemas, promoviendo la alfabetización digital desde edades tempranas.

# %% [markdown]
# 3. **Engineering (Ingeniería):** Introduce el pensamiento lógico y la resolución de problemas estructurados, fomentando habilidades como el diseño y la construcción de soluciones.

# %% [markdown]
# 4. **Arts (Arte):** Añade creatividad y pensamiento crítico, permitiendo a los estudiantes expresarse y explorar el aprendizaje a través de formas artísticas (plásticas, música, teatro).

# %% [markdown]
# 5. **Mathematics (Matemáticas):** Refuerza las habilidades numéricas y el razonamiento lógico, fundamentales en la resolución de problemas y comprensión de conceptos abstractos.

# %% [markdown]
# 6. **Social Sciences (Ciencias Sociales):** Incorpora la comprensión del entorno social, político, cultural y económico, promoviendo el desarrollo de la conciencia crítica sobre el mundo y su historia, además de habilidades de empatía y ciudadanía.

# %% [markdown]
# El enfoque STEAMS pretende desarrollar un aprendizaje **interdisciplinario** que integre estas áreas para fomentar un pensamiento más holístico y práctico.

# %% [markdown]
# Se busca que los estudiantes no solo aprendan conocimientos técnicos, sino también cómo aplicarlos creativa y críticamente en situaciones reales, promoviendo habilidades como el trabajo en equipo, la comunicación y la innovación.

# %% [markdown]
# En educación preescolar, primaria, secundaria y superior, se adapta a las diferentes etapas de desarrollo cognitivo y emocional de los estudiantes, promoviendo el aprendizaje activo y contextualizado.

# %% [markdown]
# <img src = 'https://www.campuseducacion.com/blog/wp-content/uploads/2023/03/foto01-1.jpg' width = 200>

# %% [markdown]
# # Qué estamos haciendo por la internalización en esta clase y este curso

# %% [markdown]
# Estas son mis acciones como docente de matemáticas en la Universidad de Antioquia con miras a la **internacionalización** de mi práctica docente y el desarrollo de competencias internacionales para mis estudiantes, ls cuales he estructurado con el siguiente enfoque:

# %% [markdown]
# ### 1. **Visión Global en la Formación Académica**

# %% [markdown]
#    - **Competencias Internacionales**: Asegúrate de que el contenido de tus cursos fomente habilidades que sean reconocidas globalmente.

# %% [markdown]
# Al educar a los estudiantes en **Python, LaTeX, Markdown y Jupyter Notebooks** y en la **introducción a la ciencia de datos y técnicas de Machine Learning**, estás proporcionando competencias altamente demandadas en los sectores tecnológicos y académicos a nivel internacional.

# %% [markdown]
#    - **Relevancia de los Contenidos**: Destaca cómo los temas que enseñas, como el **desarrollo del pensamiento computacional** y la **ciencia de datos**, están alineados con las necesidades globales actuales en diversas industrias, desde la tecnología hasta las ciencias naturales y sociales.

# %% [markdown]
#    - **Referencias a Estándares Internacionales**: Puedes vincular tu enseñanza a estándares internacionales de competencias en programación y ciencia de datos (por ejemplo, frameworks del **IEEE, ACM**, y estándares de la **data science** o la **computación en la nube**).

# %% [markdown]
# ### 2. **Innovación Pedagógica con Enfoque Internacional**

# %% [markdown]
#    - **Aula Invertida y ABP**: Presenta cómo tu enfoque de **aula invertida** y **aprendizaje basado en problemas (ABP)** permite a los estudiantes trabajar de manera autónoma y colaborativa, lo que los prepara para escenarios laborales internacionales que requieren autoaprendizaje y habilidades de resolución de problemas en equipo.

# %% [markdown]
#    - **Uso de Jupyter Notebooks**: El uso de **Jupyter Notebooks** en tus clases no solo facilita la **integración de código, matemáticas y texto**, sino que también es una plataforma utilizada globalmente en ambientes académicos y profesionales, lo que hace a tus estudiantes más competitivos internacionalmente.

# %% [markdown]
# ### 3. **Tecnología y Herramientas de Uso Global**

# %% [markdown]
#    - **Lenguaje Python**: Python es uno de los lenguajes de programación más usados a nivel mundial, tanto en la academia como en la industria.

# %% [markdown]
# Al formar a tus estudiantes en Python para ciencia de datos y machine learning, los preparas para operar en entornos tecnológicos globales.

# %% [markdown]
#    - **Herramientas de Ciencia Abierta**: Resalta cómo herramientas como **GitHub**, **Google Colab** y otras plataformas de código abierto están alineadas con el movimiento de **ciencia abierta**, el cual es internacionalmente reconocido y permite que los estudiantes colaboren y compartan proyectos a nivel global.

# %% [markdown]
# ### 4. **Investigación y Publicaciones Internacionales**

# %% [markdown]
#    - **Promoción de la Investigación**: Detalla cómo promueves que tus estudiantes participen en proyectos de **investigación aplicada**, con posibilidad de publicación en revistas internacionales.

# %% [markdown]
# Esto contribuye a la reputación internacional de la Universidad de Antioquia.

# %% [markdown]
#    - **Colaboraciones Internacionales**: Si has colaborado con investigadores de otras instituciones o universidades en el extranjero, menciona estos proyectos y cómo han enriquecido tu enseñanza y proporcionado a los estudiantes una visión más globalizada.

# %% [markdown]
# ## 5. **Uso del Inglés para la Internacionalización**

# %% [markdown]
#    - **Comunicación Científica en Inglés**:

# %% [markdown]
# Fomentar el aprendizaje del inglés como lengua científica es clave para que tus estudiantes puedan acceder a publicaciones internacionales, conferencias, y material académico que no está disponible en español.

# %% [markdown]
# Esto es esencial para que adquieran competencias que les permitan desempeñarse en cualquier contexto internacional.

# %% [markdown]
#    - **Material Bilingüe**: Al generar material educativo en Python, LaTeX y Markdown, considera ofrecer algunos de estos recursos en inglés, para que los estudiantes se familiaricen con el vocabulario técnico y científico internacional.

# %% [markdown]
# ### 6. **Certificaciones y Estándares Internacionales**

# %% [markdown]
#    - **Participación en Certificaciones Internacionales**: Impulsa que los estudiantes busquen certificaciones internacionales en Python o ciencia de datos (como las ofrecidas por **Coursera, edX,** o **Google**).

# %% [markdown]
# Estas certificaciones no solo validan sus competencias, sino que también incrementan el reconocimiento de la Universidad de Antioquia en el contexto internacional.

# %% [markdown]
#    - **Alineación con Acreditaciones Internacionales**: Vincula tu trabajo docente con los estándares de acreditación y certificación que garantizan que la universidad siga siendo reconocida internacionalmente.

# %% [markdown]
# Puedes vincularte con organizaciones internacionales que promuevan la excelencia en la educación y tecnología, como **ABET** para la acreditación en ingeniería y ciencias computacionales.

# %% [markdown]
# ### 7. **Proyectos Abiertos y Ciencia Reproducible**

# %% [markdown]
#    - **GitHub y Open Science**: La utilización de **GitHub** para almacenar los proyectos y materiales de enseñanza en repositorios públicos permite que otros investigadores y educadores internacionales puedan revisar y replicar tu trabajo.

# %% [markdown]
# Esto contribuye a la creación de una red de colaboración científica abierta.

# %% [markdown]
#    - **Transparencia y Reproducibilidad**: La ciencia de datos y machine learning están profundamente ligados a la reproducibilidad.

# %% [markdown]
# Asegura que tus estudiantes desarrollen prácticas de transparencia y documentación en la investigación, que son pilares en la comunidad científica global.

# %% [markdown]
# ### 8. **Participación en Redes y Conferencias Internacionales**

# %% [markdown]
#    - **Presentación en Conferencias Internacionales**: Destaca cómo tu participación en conferencias internacionales (como la **ASCOLFA** o eventos sobre educación en matemáticas) contribuye al prestigio de la universidad y permite que tus prácticas sean evaluadas y reconocidas a nivel global.

# %% [markdown]
#    - **Promoción de Estudiantes en Eventos Internacionales**: Impulsa la participación de tus estudiantes en competiciones internacionales de programación o hackathons, como los organizados por **Google**, **ACM** o **Kaggle**.

# %% [markdown]
# Esto no solo desarrolla sus habilidades, sino que también visibiliza el talento de la Universidad de Antioquia a nivel global.
#
# ---

# %% [markdown]
# Con esta estrategia, presento mis acciones docentes en términos de:
#
# * competencias internacionales,
# * innovación pedagógica,
# * tecnología,
# * investigación y
# * participación en redes globales,
#
# asegurando que mi práctica esté alineada con los estándares internacionales y que mis estudiantes estén preparados para competir en contextos internacionales.

# %% [markdown]
# ### **Metodología de Enseñanza: Aprendizaje Basado en Problemas y Proyectos (ABPP)**

# %% [markdown]
# El **Aprendizaje Basado en Problemas y Proyectos (ABPP)** es una metodología educativa que integra los enfoques del **Aprendizaje Basado en Problemas (ABP)** y el **Aprendizaje Basado en Proyectos (PBL, por sus siglas en inglés)**.

# %% [markdown]
# Es especialmente útil para la formación de futuros docentes, ingenieros y administradores, ya que combina el desarrollo de habilidades prácticas con el pensamiento crítico y reflexivo.

# %% [markdown]
# A continuación, se presenta una descripción adaptada a la enseñanza de las matemáticas en educación infantil, Licenciatura en Matemáticas, Ingeniería Agropecuaria y Administración de Empresas:
#
# ---

# %% [markdown]
# ### **1. Fundamentos del ABPP**

# %% [markdown]
# El ABPP se basa en:
# - **Resolución de Problemas Reales:** Los estudiantes analizan y resuelven problemas auténticos relacionados con su área de formación, fomentando la aplicación práctica del conocimiento.

# %% [markdown]
# - **Proyectos como Herramientas Integradoras:** Los proyectos permiten desarrollar habilidades interdisciplinarias y ofrecer soluciones concretas a los problemas planteados.

# %% [markdown]
# - **Aprendizaje Activo:** Los estudiantes son responsables de su aprendizaje y participan activamente en el proceso de investigación, diseño y solución.
#
# ---

# %% [markdown]
# ### **2. Aplicación del ABPP en Áreas Específicas**
#
# #### **Educación Infantil (Licenciatura en Educación Infantil)**
# - **Enfoque:** Desarrollo del pensamiento matemático en la infancia desde contextos lúdicos, familiares y culturales.
# - **Problemas típicos:**
#   - ¿Cómo enseñar los números naturales mediante actividades prácticas y juegos?
#   - ¿Qué estrategias pueden emplearse para abordar el concepto de cantidad en edades tempranas?

# %% [markdown]
# - **Proyectos:** Diseño de secuencias didácticas que usen Python, Jupyter Notebooks y materiales manipulativos para enseñar matemáticas de forma interactiva.

# %% [markdown]
# - **Competencias desarrolladas:**
#   - Uso de herramientas tecnológicas para diseñar actividades educativas.
#   - Comprensión del desarrollo cognitivo infantil y su relación con las matemáticas.

# %% [markdown]
# #### **Licenciatura en Matemáticas**
# - **Enfoque:** Resolución de problemas matemáticos aplicados y profundización teórica en áreas como análisis matemático y modelado.
# - **Problemas típicos:**
#   - ¿Cómo se pueden resolver ecuaciones diferenciales aplicadas a modelos físicos o económicos?
#   - ¿Cómo modelar fenómenos naturales mediante funciones matemáticas?

# %% [markdown]
# - **Proyectos:**
#   - Desarrollo de software educativo para explorar conceptos matemáticos.
#   - Aplicación de modelado matemático para resolver problemas reales en otras disciplinas.
# - **Competencias desarrolladas:**
#   - Dominio de la matemática teórica y aplicada.
#   - Uso de tecnología para la enseñanza y la investigación.

# %% [markdown]
# #### **Ingeniería Agropecuaria**
# - **Enfoque:** Modelado matemático y análisis de datos para mejorar la producción agrícola y la gestión de recursos.
# - **Problemas típicos:**
#   - ¿Cómo modelar el crecimiento de cultivos considerando variables climáticas?
#   - ¿Cómo optimizar el uso del agua en sistemas de riego mediante análisis matemático?

# %% [markdown]
# - **Proyectos:**
#   - Desarrollo de modelos predictivos con Python y bibliotecas de aprendizaje automático.
#   - Implementación de proyectos que combinen matemáticas y ciencias de datos para resolver problemas agrícolas.

# %% [markdown]
# - **Competencias desarrolladas:**
#   - Integración de matemáticas con tecnologías avanzadas.
#   - Resolución de problemas agropecuarios mediante análisis y modelado.

# %% [markdown]
# #### **Administración de Empresas**

# %% [markdown]
# - **Enfoque:** Uso de las matemáticas y la ciencia de datos para la toma de decisiones estratégicas.
# - **Problemas típicos:**
#   - ¿Cómo identificar patrones de comportamiento del consumidor usando series de tiempo?
#   - ¿Qué estrategias matemáticas pueden optimizar la asignación de recursos en una empresa?

# %% [markdown]
# - **Proyectos:**
#   - Implementación de modelos de análisis financiero y simulaciones.
#   - Desarrollo de dashboards interactivos para la gestión de datos empresariales.

# %% [markdown]
# - **Competencias desarrolladas:**
#   - Habilidad para interpretar datos matemáticos en contextos de negocio.
#   - Capacidad para diseñar soluciones basadas en datos.
#
# ---

# %% [markdown]
# ### **3. Beneficios del ABPP**

# %% [markdown]
# - **Desarrollo de competencias clave:**
#   - Pensamiento crítico y creativo.
#   - Trabajo colaborativo.
#   - Comunicación efectiva.
#   - Uso de herramientas tecnológicas avanzadas.
# - **Adaptación al contexto laboral:** Los estudiantes aprenden a enfrentar desafíos del mundo real y a diseñar soluciones prácticas y aplicables.

# %% [markdown]
# - **Flexibilidad e interdisciplinariedad:** La metodología se adapta a diversas áreas, fomentando el aprendizaje integrado.
#
# ---

# %% [markdown]
# ### **4. Ejemplo General de Implementación**

# %% [markdown]
# 1. **Identificación del problema:** Se plantea un desafío concreto, como modelar el crecimiento poblacional de una comunidad rural (Ingeniería Agropecuaria) o diseñar una estrategia para enseñar fracciones a niños de 8 años (Educación Infantil).

# %% [markdown]
# 2. **Formación de equipos:** Los estudiantes trabajan en grupos, distribuyendo roles y tareas.
# 3. **Investigación y diseño:** Los estudiantes investigan el problema, proponen soluciones y diseñan un proyecto.
# 4. **Implementación:** Se desarrolla el proyecto, como una herramienta tecnológica o una propuesta pedagógica.
# 5. **Evaluación:** Los estudiantes presentan sus resultados en un informe o una exposición, recibiendo retroalimentación de sus compañeros y docentes.
#
# ---

# %% [markdown]
# El ABPP es una metodología versátil que conecta el conocimiento teórico con la práctica, preparando a los estudiantes para los retos de sus profesiones en la enseñanza de la matemática, la ingeniería y la administración.

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
# [Aprender a obtener el sí sin ceder]()

# %% [markdown]
# ## Título de la clase: Simplificación de expresiones que tienen radicales
#
# []()

# %% [markdown]
# # Estructura general para todas las clases
#
# Dame, por favor, un diseño de clase, con el enfoque: "Aula Invertida, STEAMS y De aprendizaje basado en problemas y proyectos(ABPP)" sobre: "Simolificación de expresiones que tienen radicales", siguiendo la estructura:
#
# 1. Título de la clase
# 2. Objetivos de aprendizaje que incluyan los indicadores del logro de estos objetivos.
# 3. Un mapa conceptual que resuma la clase elaborado en Graphviz de python con nodos y edges de diferentes formas, colores y rellenos y renderizado en la siguiente ubicación: `"C:/Users/marco/Descargas"`. No olvides el parámetro `view = True` ppara el método render() de graphviz.
# 4. Dame elementos históricos y epistemológicos asociados a esta clase, pero contados como un cuento al estilo de un cuentero antioqueño en Colombia. Incluye imágenes de los protagonistas históricos de esta clase.
# 5. Contenido de la clase. Que el contenido parta de una situación real para llegar a una constitución del modelo matemático que represente tal situación real.
# 6. Actividades de aprendizaje
# 7. Incluye una canción o un poema que ayude a interiorizar y fijar los conceptos asociados a esta clase.
# 8. Tarea o actividades de ejercitación y fijación
# 9. Evaluación incluyendo diez proyectos, un ejemplo de quiz (de tres preguntas) y un ejemplo de parcial (de cinco puntos)
# 10. Diseño de actividad de retroalimentación.
# 11. Dame un vocabulario y frases del idioma inglés asociadas a esta clase.
#
# Pero  que este diseño sea para que el estudiante pueda aprender experimentando en cuadernos Jupyter con funciones de usuario y animaciones y visualizaciones en python. En particular utiliza para el diseño de clase a Numpy, Pandas, SymPy, Matplotlib.pyplot, Seaborn, Plotly, ipywidgets, matplotlib.animation y Jupyter Notebook.  Cada vez que utilices `matplotlib.animacion` no olvides incluir el uso de `IPython. display` para la rederización de estas animaciones a través de Jupyter Notebook. No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dolar $ para que VS Code si me renderize estas expresiones del lenguaje latex. Cuando vallas a utilizar ipywidgets ten en cuenta la siguiente importación inicial para garantizar que la visualización interactiva si se renderize en VS Code: import numpy as np
# import matplotlib.pyplot as plt
# import ipywidgets as widgets
# from IPython.display import display, clear_output
# from matplotlib.patches import Rectangle
#
# # Configuración inicial para visualización estática
# %matplotlib inline

# %%
path_image = r'C:/Users/marco/Descargas'
def save_fig(nombre_archivo_imagen):
    import os 
    import matplotlib.pyplot as plt 
    imagen_path = os.path.join(path_image, nombre_archivo_imagen)
    plt.savefig(imagen_path, bbox_inches='tight')

# %% [markdown]
# # Título de la clase
# **Simplificación de Expresiones con Radicales: Una Aventura Matemática**
#
# ---
#
# ## 1. Objetivos de aprendizaje
#
# ### Objetivos Generales:
# - Comprender y aplicar los principios de la simplificación de expresiones con radicales en la resolución de problemas matemáticos.
# - Desarrollar habilidades experimentales en Jupyter Notebook con el uso de Python para visualizar y manipular expresiones radicales.
# - Conectar la matemática con aplicaciones prácticas en ciencias, tecnología, ingeniería, arte y matemáticas (STEAM).
#
# ### Indicadores de Logro:
# - Identifica y agrupa términos semejantes con radicales en una expresión algebraica.
# - Utiliza funciones de Python para simplificar y operar expresiones con radicales.
# - Desarrolla simulaciones y visualizaciones interactivas en Jupyter Notebook.
#
# ---
#
# ## 2. Mapa Conceptual
# El siguiente código en Python genera un mapa conceptual utilizando Graphviz y lo guarda en la ruta indicada:
#
# ```python
# from graphviz import Digraph
#
# dot = Digraph('Simplificacion_Radicales', format='png')
# dot.attr(rankdir='LR')
#
# dot.node('A', 'Expresiones con Radicales', shape='box', style='filled', fillcolor='lightblue')
# dot.node('B', 'Propiedades de los Radicales', shape='ellipse', style='filled', fillcolor='lightgreen')
# dot.node('C', 'Simplificación de Radicales', shape='diamond', style='filled', fillcolor='yellow')
# dot.node('D', 'Ejemplos con Python', shape='parallelogram', style='filled', fillcolor='orange')
#
# dot.edge('A', 'B')
# dot.edge('B', 'C')
# dot.edge('C', 'D')
#
# dot.render("C:/Users/marco/Descargas/Simplificacion_Radicales", view=True)
# ```
#
# ---
#
# ## 3. Elementos Históricos y Epistemológicos
#
# ### "La Historia del Sabio Raíz y su Misterio Matemático"
#
# Había una vez en la antigua Babilonia un sabio llamado **Raíz Ibn Al-Khwarizmi**, quien se dedicaba a desentrañar los secretos de los números ocultos. Se dice que una noche, observando las estrellas, descubrió que algunos números podían descomponerse en partes exactas, formando lo que hoy llamamos **radicales**.
#
# Un día, Raíz se encontró con un joven griego llamado **Pitágoras**, quien le habló de un triángulo donde la hipotenusa no podía expresarse como un número entero. "Es una magnitud inexacta", dijo Pitágoras, y Raíz respondió: "Es un número que vive en las profundidades del infinito". Así, los radicales se convirtieron en el puente entre lo finito y lo infinito en matemáticas.
#
# (Imágenes recomendadas: Pitágoras, Al-Khwarizmi, manuscritos matemáticos antiguos.)
#
# ---
#
# ## 4. Contenido de la Clase
#
# ### Situación Real:
# Imagina que eres un arquitecto diseñando un puente colgante y necesitas calcular longitudes exactas de cables y tensores. Muchas veces, estas medidas no son números enteros, sino expresiones con radicales.
#
# **Modelo Matemático:**
# - Se introducen las propiedades de los radicales con ejemplos prácticos.
# - Se usan Jupyter Notebooks para experimentar con simplificación de radicales.
# - Se introduce Python para automatizar la simplificación:
#
# ```python
# from sympy import symbols, sqrt, simplify
#
# x = symbols('x')
# expr = sqrt(50) + sqrt(18) - sqrt(8)
# simplified_expr = simplify(expr)
# print(simplified_expr)
# ```
#
# ---
#
# ## 5. Actividades de Aprendizaje
# - Visualización interactiva de radicales con **Matplotlib** y **ipywidgets**.
# - Creación de una función en Python que simplifique expresiones con radicales.
#
# ---
#
# ## 6. Canciones o Poemas
#
# **Poema: "El Misterio del Radical"**
#
# Cuando un número esconde su ser,
# y en sus entrañas se puede ver,
# raíces y cifras en dulce danzar,
# se revelan al mundo al simplificar.
#
# ---
#
# ## 7. Tareas y Ejercitación
# - Resolver una lista de 20 ejercicios con radicales.
# - Crear un programa en Python que identifique y simplifique expresiones radicales.
#
# ---
#
# ## 8. Evaluación
#
# ### Proyectos:
# 1. Análisis de medidas en estructuras arquitectónicas.
# 2. Simulación de distribución de fuerzas usando radicales.
#
# ### Quiz:
# 1. Simplifica: $ \sqrt{72} + \sqrt{50} - \sqrt{8} $
# 2. Explica el significado de un radical en la geometría.
#
# ### Parcial:
# 1. Dado $ f(x) = \sqrt{x^2 + 4x + 4} $, simplifícalo.
# 2. Crea una función en Python que simplifique cualquier expresión con radicales.
#
# ---
#
# ## 9. Actividad de Retroalimentación
# - Se realizará una sesión de repaso donde los estudiantes compartirán sus descubrimientos en Jupyter Notebooks.
#
# ---
#
# ## 10. Vocabulario y Frases en Inglés
#
# - **Radical Expression** - Expresión radical
# - **Square Root** - Raíz cuadrada
# - **Simplification** - Simplificación
# - **Mathematical Modeling** - Modelado matemático
# - **Real-World Application** - Aplicación en el mundo real
#
# ---
#
# Este diseño de clase permite que los estudiantes experimenten activamente en Jupyter Notebook, utilizando visualizaciones interactivas y animaciones para reforzar el aprendizaje. ¡Espero que te sirva! 🚀

# %% [markdown]
# # Implementación de esta clase
#
# # Título de la clase
# **Simplificación de Expresiones con Radicales: Una Aventura Matemática**
#
# ---
#
# ## 1. Objetivos de aprendizaje
#
# ### Objetivos Generales:
# - Comprender y aplicar los principios de la simplificación de expresiones con radicales en la resolución de problemas matemáticos.
# - Desarrollar habilidades experimentales en Jupyter Notebook con el uso de Python para visualizar y manipular expresiones radicales.
# - Conectar la matemática con aplicaciones prácticas en ciencias, tecnología, ingeniería, arte y matemáticas (STEAM).
#
# ### Indicadores de Logro:
# - Identifica y agrupa términos semejantes con radicales en una expresión algebraica.
# - Utiliza funciones de Python para simplificar y operar expresiones con radicales.
# - Desarrolla simulaciones y visualizaciones interactivas en Jupyter Notebook.
#
# ---
#
# ## 2. Mapa Conceptual
# El siguiente código en Python genera un mapa conceptual utilizando Graphviz y lo guarda en la ruta indicada:
#
# ```python
# from graphviz import Digraph
#
# dot = Digraph('Simplificacion_Radicales', format='png')
# dot.attr(rankdir='LR')
#
# dot.node('A', 'Expresiones con Radicales', shape='box', style='filled', fillcolor='lightblue')
# dot.node('B', 'Propiedades de los Radicales', shape='ellipse', style='filled', fillcolor='lightgreen')
# dot.node('C', 'Simplificación de Radicales', shape='diamond', style='filled', fillcolor='yellow')
# dot.node('D', 'Ejemplos con Python', shape='parallelogram', style='filled', fillcolor='orange')
#
# dot.edge('A', 'B')
# dot.edge('B', 'C')
# dot.edge('C', 'D')
#
# dot.render("C:/Users/marco/Descargas/Simplificacion_Radicales", view=True)
# ```
#
# ---
#
# ## 3. Elementos Históricos y Epistemológicos
#
# ### "La Historia del Sabio Raíz y su Misterio Matemático"
#
# Había una vez en la antigua Babilonia un sabio llamado **Raíz Ibn Al-Khwarizmi**, quien se dedicaba a desentrañar los secretos de los números ocultos. Se dice que una noche, observando las estrellas, descubrió que algunos números podían descomponerse en partes exactas, formando lo que hoy llamamos **radicales**.
#
# Un día, Raíz se encontró con un joven griego llamado **Pitágoras**, quien le habló de un triángulo donde la hipotenusa no podía expresarse como un número entero. "Es una magnitud inexacta", dijo Pitágoras, y Raíz respondió: "Es un número que vive en las profundidades del infinito". Así, los radicales se convirtieron en el puente entre lo finito y lo infinito en matemáticas.
#
# (Imágenes recomendadas: Pitágoras, Al-Khwarizmi, manuscritos matemáticos antiguos.)
#
# ---
#
# ## 4. Contenido de la Clase
#
# ### Situación Real:
# Imagina que eres un arquitecto diseñando un puente colgante y necesitas calcular longitudes exactas de cables y tensores. Muchas veces, estas medidas no son números enteros, sino expresiones con radicales.
#
# **Modelo Matemático:**
# - Se introducen las propiedades de los radicales con ejemplos prácticos.
# - Se usan Jupyter Notebooks para experimentar con simplificación de radicales.
# - Se introduce Python para automatizar la simplificación:
#
# ```python
# from sympy import symbols, sqrt, simplify
#
# x = symbols('x')
# expr = sqrt(50) + sqrt(18) - sqrt(8)
# simplified_expr = simplify(expr)
# print(simplified_expr)
# ```
#
# ---
#
# ## 5. Actividades de Aprendizaje
# - Visualización interactiva de radicales con **Matplotlib** y **ipywidgets**.
# - Creación de una función en Python que simplifique expresiones con radicales.
#
# ---
#
# ## 6. Canciones o Poemas
#
# **Poema: "El Misterio del Radical"**
#
# Cuando un número esconde su ser,
# y en sus entrañas se puede ver,
# raíces y cifras en dulce danzar,
# se revelan al mundo al simplificar.
#
# ---
#
# ## 7. Tareas y Ejercitación
# - Resolver una lista de 20 ejercicios con radicales.
# - Crear un programa en Python que identifique y simplifique expresiones radicales.
#
# ---
#
# ## 8. Evaluación
#
# ### Proyectos:
# 1. Análisis de medidas en estructuras arquitectónicas.
# 2. Simulación de distribución de fuerzas usando radicales.
#
# ### Quiz:
# 1. Simplifica: $ \sqrt{72} + \sqrt{50} - \sqrt{8} $
# 2. Explica el significado de un radical en la geometría.
#
# ### Parcial:
# 1. Dado $ f(x) = \sqrt{x^2 + 4x + 4} $, simplifícalo.
# 2. Crea una función en Python que simplifique cualquier expresión con radicales.
#
# ---
#
# ## 9. Actividad de Retroalimentación
# - Se realizará una sesión de repaso donde los estudiantes compartirán sus descubrimientos en Jupyter Notebooks.
#
# ---
#
# ## 10. Vocabulario y Frases en Inglés
#
# - **Radical Expression** - Expresión radical
# - **Square Root** - Raíz cuadrada
# - **Simplification** - Simplificación
# - **Mathematical Modeling** - Modelado matemático
# - **Real-World Application** - Aplicación en el mundo real
#
# ---
#
# Este diseño de clase permite que los estudiantes experimenten activamente en Jupyter Notebook, utilizando visualizaciones interactivas y animaciones para reforzar el aprendizaje. ¡Espero que te sirva! 🚀

# %% [markdown]
# # Terminología
#
# 1. El alcance del radical
# 2. La radicación distribuye o reparte para productos.

# %% [markdown]
# # Dame 20 ejercicios de suma de términos semejantes que tengan radicales y otras expresiones algebraicas. Diseñame la lista con complejidad creciente.
#
#
# Aquí tienes 20 ejercicios de suma de términos semejantes que incluyen radicales y expresiones algebraicas, organizados en orden de complejidad creciente:
#
# Aquí tienes la lista con las expresiones matemáticas delimitadas por el signo de dólar `$` para que Visual Studio Code las renderice correctamente:
#
# ### **Nivel 1: Básico (Suma de términos semejantes con radicales y coeficientes enteros)**
# 1. $3\sqrt{2} + 5\sqrt{2}$
# 2. $7\sqrt{3} - 2\sqrt{3}$
# 3. $4x\sqrt{5} + 6x\sqrt{5}$
# 4. $9\sqrt{7} - 4\sqrt{7} + 2\sqrt{7}$
# 5. $2\sqrt{6} + 3\sqrt{6} - \sqrt{6}$
#
# ### **Nivel 2: Intermedio (Incorporando expresiones algebraicas y diferentes raíces)**
# 6. $5x\sqrt{2} + 3x\sqrt{2} - x\sqrt{2}$
# 7. $2y\sqrt{5} + 7y\sqrt{5} - 4y\sqrt{5}$
# 8. $3a\sqrt{3} + 2a\sqrt{3} - 5a\sqrt{3}$
# 9. $6\sqrt{8} + 2\sqrt{2}$ *(Requiere simplificación de radicales)*
# 10. $5\sqrt{18} - 2\sqrt{2} + \sqrt{50}$ *(Requiere simplificación de radicales y agrupación de términos semejantes)*
#
# ### **Nivel 3: Avanzado (Combinando variables, coeficientes fraccionarios y raíces diferentes)**
# 11. $\frac{1}{2}x\sqrt{3} + \frac{3}{4}x\sqrt{3} - \frac{1}{4}x\sqrt{3}$
# 12. $4a\sqrt{12} + 3a\sqrt{3}$ *(Requiere simplificación de radicales y suma de términos semejantes)*
# 13. $7b\sqrt{27} - 2b\sqrt{3} + 3b\sqrt{12}$ *(Requiere simplificación y agrupación)*
# 14. $\sqrt{50} + \sqrt{72} - \sqrt{32}$ *(Requiere simplificación de radicales y agrupación)*
# 15. $2x\sqrt{18} + 3x\sqrt{8} - 4x\sqrt{2}$ *(Requiere simplificación y suma de términos semejantes)*
#
# ### **Nivel 4: Desafío (Expresiones más complejas con múltiples términos y operaciones combinadas)**
# 16. $(3\sqrt{5} + 4\sqrt{7}) + (5\sqrt{5} - 2\sqrt{7})$
# 17. $(6a\sqrt{2} - 4b\sqrt{3}) + (2a\sqrt{2} + 5b\sqrt{3})$
# 18. $(3x + 2)\sqrt{6} + (5x - 3)\sqrt{6}$
# 19. $(2y + 5)\sqrt{10} + (3y - 2)\sqrt{10} - y\sqrt{10}$
# 20. $(4m - 3n)\sqrt{7} + (2n - 5m)\sqrt{7}$
#
# Ahora Visual Studio Code debería renderizar correctamente estas expresiones en formato matemático. ¡Espero que te sirva! 😊

# %% [markdown]
# # ARTÍCULO 1. Definir el calendario académico para los diferentes programas de pregrado de los campus
# regionalizados, correspondiente al primer periodo académico del año 2025, así:
# * Oferta 28 de enero de 2025
# * Matrícula 30 de enero de 2025
# * Ajustes 03 al 10 de febrero de 2025
# * Inicio de clases 10 de febrero de 2025
# * Límite evaluación del 40% 06 de abril de 2025
# * Terminación de clases 08 de junio de 2025
# * Exámenes finales 09 al 15 de junio de 2025
# * Habilitación y validación 16 al 22 de junio de 2025
# * Terminación oficial 23 de junio de 2025

# %% [markdown]
# # Componente de manejo de calculadora Casio asociado al objetivo de aprendizaje de esta clase
#
# ## Pasos para lograr el objetivo de aprendizaje con la experimentación en la calculadora Casio 991LA cw

# %% [markdown]
# # Cursos que orienta el profesor Marco Julio Cañas Campillo en 2025
#
# 1. Práctica Pedagógica V para Licenciatura en Educación Infantil
# 2. Fundamentos de Lógica para Licenciatura en Matemáticas
# 3. Análisis Numérico para Licenciatura en Matemáticas.
# 4. Cálculo Vectorial para Ingeniería Agropecuaria

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12: Cálculo Vectorial
# * Martes 8-12 M: Fundamentos de Aritmética.
# * Miércoles 8 a 12 M: Fundamentos de la Lógica
# * Jueves 2 a 6 PM: Desarrollo del pensamiento matemático en la infancia.
# * Viernes 8 - 12 M: Desarrollo del pensamiento matemático en la infancia.
# * Sábados 8-12 Asesorías y espacio para retroalimentación y apoyo al trabajo independiente.

# %% [markdown]
# # Horarios de monitoría y asesoría
#
# Coordinador de los cursos de la Facultad de Educación para regiones:
#
# Andrés Vélez: regioneducacion.fedu@udea.edu.co
# Coordinador Regiones
# Facultad de Educación
# Universidad de Antioquia

# %% [markdown]
# ## Monitor Manuel San Juan Serrano
#
# Contactar escribiendo al correo: manuel.serrano1@udea.edu.co

# %% [markdown]
# Martes y jueves de 8 - 12
# Miércoles 10 - 12 y de 2 a 4 PM
# Sábado: 8 - 12

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [CALCULO I DE UNA VARIABLE Ron Larson-Bruce Edwards. Mc Graw Hill. 9º Edición](https://www.academia.edu/42139251/CALCULO_I_DE_UNA_VARIABLE_Ron_Larson_Bruce_Edwards_Mc_Graw_Hill_9o_Edici%C3%B3n)
#
#
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://bibliotecadigital.udea.edu.co/handle/10495/3010)
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://tanthiamhuat.wordpress.com/wp-content/uploads/2018/03/deeplearningwithpython.pdf)
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)
#
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)
#
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
#
#
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Apéndice sobre calendarios y coordinaciones
#
# A continuación le envío el horario de la asignatura Cálculo Vectorial
#
# Días:
# Lunes - Hora: 7:00 a 12:00M
# Fechas:
# Febrero: 10-17-24
#  Marzo: 3-10-17-31
# Abril:7-21-28
# Mayo:5-12-19
#
# Agradezco su apoyo, y si presenta alguna dificultad puede contactarme.
#
# Cordialmente,
# Juan Felipe Rivera Hernández
# Contacto: 3106314300

# %% [markdown]
# # Clase de análisis numérico los Martes de 8 a 12 del medio día.
