# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/analisis_numerico/blob/main/4_planifica_implementa/0_formatos_clase/4_formato_clase_analisis_numerico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/analisis_numerico/blob/main/4_planifica_implementa/0_formatos_clase/4_formato_clase_analisis_numerico.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
import qrcode
from IPython.display import display
from PIL import Image

def generar_qr(url, version=1, box_size=10, border=4, fill_color="black", back_color="white"):
    """
    Genera y muestra un código QR para una URL dada en un Jupyter Notebook.
    
    Parámetros:
    - url: La URL para la cual generar el código QR
    - version: Tamaño del QR (1-40, donde 1 es el más pequeño)
    - box_size: Número de píxeles por cada "caja" del QR
    - border: Grosor del borde blanco alrededor del QR (en cajas)
    - fill_color: Color del código QR
    - back_color: Color de fondo del código QR
    
    Retorna:
    - Muestra el código QR directamente en el notebook
    - Retorna el objeto QR generado
    """
    # Configurar el generador de QR
    qr = qrcode.QRCode(
        version=version,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=box_size,
        border=border,
    )
    
    # Añadir la URL al QR
    qr.add_data(url)
    qr.make(fit=True)
    
    # Crear la imagen del QR
    img = qr.make_image(fill_color=fill_color, back_color=back_color)
    
    # Mostrar la imagen en el notebook
    display(img)
    
    return img

# Ejemplo de uso:
# generar_qr("https://www.ejemplo.com")

# %%
generar_qr("")

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso de Análisis Numérico:](https://github.com/marco-canas/analisis_numerico/blob/main/2_programa_curso/2_programa_curso_analisis_numerico.md)

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = 'https://github.com/marco-canas/analisis_numerico/blob/main/7_images/asesor%C3%ADa_nov_1_2025.jpg?raw=true'>

# %% [markdown]
# Reconocimiento a las profesoras destacadas en enseñanza de la matemática en Colombia

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde el archivo CSV
path = 'C:/Users/marco/Documentos/docencia/groups_list/analisis_numerico.xlsx'
df = pd.read_excel(path)
df.index = np.arange(1, len(df) + 1)  # Cambiar el índice para que empiece en 1
df.head()
# Out:
#        Cedula                            Nombre  \
# 1  1067281024        ALVAREZ GOEZ DAIRO ESTEBAN
# 2  1041086439     CASTILLO SIERRA SHIRLIS SARAY
# 3  1045419649  ESPINOSA ESPINOSA LILIANA ANDREA
# 4  1040494191           GARCIA PADILLA JHONATAN
# 5  1038131529        HOYOS ARRIETA ELIECER JOSE
#
#                            Email   p1   q2  p2
# 1     dairo.alvarez1@udea.edu.co  2.8  NaN NaN
# 2   shirlis.castillo@udea.edu.co  1.7  NaN NaN
# 3  lilianaa.espinosa@udea.edu.co  1.7  NaN NaN
# 4   jhonatan.garcia1@udea.edu.co  3.0  NaN NaN
# 5        jose.hoyos2@udea.edu.co  5.0  3.5 NaN

# %% [markdown]
# # Principios de mi labor docente

# %% [markdown]
# ## Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# <img src = 'https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png' width = 200>

# %% [markdown]
# # Metodología de Aprendizaje Basado en Problemas y Proyectos (ABPP)

# %% [markdown]
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg' width = 200>

# %% [markdown]
# # Desarrollo del pensamiento computacional con Lenguajes Python, R; y con archivos Markdown y R-Markdown orientado a la formación en ciencia de datos

# %% [markdown]
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg' width = 200>

# %% [markdown]
# # Principio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto

# %% [markdown]
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1' width = 200>

# %% [markdown]
# El enfoque STEAMS en educación preescolar, primaria y secundaria es una extensión del enfoque STEM (Ciencia, Tecnología, Ingeniería y Matemáticas) y su variante STEAM, que incorpora el Arte.

# %% [markdown]
# # Y el enfoque de TRRS de Duval

# %% [markdown]
# # Estructura general para todas las clases
#
# Dame, por favor, un diseño de clase, con el enfoque: "Aula Invertida, STEAMS y De aprendizaje basado en problemas y proyectos(ABPP)" sobre: "Métodos numéricos para resolver sistemas de ecuaciones lineales", siguiendo la estructura:
#
# 1. Título de la clase
#
# 2. Objetivos de aprendizaje que incluyan los indicadores del logro de estos objetivos.
#
# 3. Un mapa conceptual que resuma la clase elaborado en Graphviz de Python con nodos y edges de diferentes formas, colores y rellenos y renderizado en la siguiente ubicación: `"C:/Users/marco/Downloads"`. No olvides el parámetro `view = True` para el método `render()` de Graphviz. Para este mapa controla las superposiciones de los nodos con: graph [overlap=false]; // Elimina superposiciones (puede aumentar el espacio)
# graph [overlap="scalexy"]; // Escala el gráfico para evitar overlaps
# graph [overlap="compress"]; // Comprime el grafo sin overlaps
#
# 4. Dame elementos históricos y epistemológicos asociados a esta clase, pero contados como un cuento al estilo de un cuentero antioqueño en Colombia. Incluye imágenes de los protagonistas históricos de esta clase.
#
# 5. Contenido de la clase. Que el contenido parta de una situación real para llegar a una constitución del modelo matemático que represente tal situación real.
#
#
# 7. Actividades de aprendizaje: que incluya pruebas de escritorio para los algoritmos en forma verbal y seudo código, diagrama de flujo, y la implementación del algoritmo en lenguaje Python.
#
# 8. Incluye una canción o un poema que ayude a interiorizar y fijar los conceptos asociados a esta clase.
#
# 9.  Tarea o actividades de ejercitación y fijación.
#
# 10. Evaluación incluyendo diez proyectos, un ejemplo de quiz y un ejemplo de parcial.
#
# 11. Diseño de actividad de retroalimentación.
#
# 12. Dame un vocabulario y frases del idioma inglés asociadas a esta clase.
#
# 13.  Incluye apéndice para la clase sobre desarrollo de habilidades para trabajar en equipo y de asertividad y empatía para relacionarnos. También elementos de la inteligencia emocional para presentar pruebas sin temor y sin realizar fraude en ellas. Y Actividades para desarrollar la habilidad de la Tolerancia
#
# 14. Incluye 5 referentes en didáctica de la matemática que estén de acuerdo a la propuesta didáctica de esta clase. Adiciona a estos referentes a Raymond Duval (Representaciones y cambios de representación para la adquisición de conceptos matemáticos) y a Jeannette Wing (Desarrollo del pensamiento computacional). Dejame todos estos referentes ordenados de acuerdo a las normas APA. Incluye un referente en didáctica de la matemática que fundamente el uso del Enfoque de Aula Invertida, uno que fundamente el enfoque STEAMS y finalmente otro que fundamente el enfoque de Aprendizaje Basado en Problemas y Proyectos (ABPP)
#
#
# Pero  que este diseño sea para que el estudiante pueda aprender experimentando en cuadernos Jupyter con funciones de usuario y animaciones y visualizaciones en Python.
#
# En particular utiliza para el diseño de clase a Numpy, Pandas, SymPy, Matplotlib.pyplot, Seaborn, Plotly, ipywidgets, matplotlib.animation y Jupyter Notebook.
#
# Cada vez que utilices `matplotlib.animacion` no olvides incluir el uso de `IPython. display` para la renderización de estas animaciones a través de Jupyter Notebook.
#
# No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dólar $ para que VS Code si me renderice estas expresiones del lenguaje latex. Cuando vallas a utilizar ipywidgets ten en cuenta la siguiente importación inicial para garantizar que la visualización interactiva si se renderice en VS Code:
#
# import numpy as np
# import matplotlib.pyplot as plt
# import ipywidgets as widgets
# from IPython.display import display, clear_output
# from matplotlib.patches import Rectangle
#
# * Obtenga el libro guía: Métodos Numéricos Usando Python, [aquí:](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://librosoa.unam.mx/bitstream/handle/123456789/3416/MNPython.pdf?sequence=1&isAllowed=y)
# * Obtenga el programa del curso [aquí](https://github.com/marco-canas/analisis_numerico/blob/main/2_programa_curso/2_programa_curso_analisis_numerico.md)
# * El cronograma o clase  a clase de este curso lo puede obtener [aquí](https://github.com/marco-canas/analisis_numerico/blob/main/2_programa_curso/3_cronograma_o_clase_a_clase.md)

# %% [markdown]
# [![Archivo Friedrich Gauss.jpg - Wikipedia, la enciclopedia libre](https://images.openai.com/static-rsc-1/x3v6JN0nbbzWs5K7Vq-FeaeNKPnM5LTgEumzYooT8LZr_qdPaOHSlrukmzVERQLF4sxkgASUW6Ja3GT4TqKi_gVoLYIj8c4RcYCLVX12HFfXgOtgus49_EOUxRlU_OeOLhYejw8X4EGt23uv41LkMA)](https://es.wikipedia.org/wiki/Archivo%3ACarl_Friedrich_Gauss.jpg?utm_source=chatgpt.com)
#
# ¡Perfecto — aquí tienes el diseño de clase completo y listo para usar en Jupyter/VS Code! Lo entrego en español, con código de ejemplo (Graphviz y Python), contenidos matemáticos con LaTeX delimitado por `$...$`, actividades, evaluaciones, referencias APA, y todo pensado para un enfoque **Aula Invertida + STEAMS + ABPP**.
# Voy directo a la estructura que pediste.
#
# # 1. Título de la clase
#
# **Métodos numéricos para resolver sistemas de ecuaciones lineales: experimentación en Jupyter con algoritmos directos e iterativos**
#
# ---
#
# # 2. Objetivos de aprendizaje y sus indicadores
#
# **Objetivo general**
#
# * El/la estudiante será capaz de modelar una situación real con un sistema lineal, aplicar y comparar métodos numéricos directos e iterativos para resolverlo, e interpretar la solución y su precisión usando herramientas interactivas en Jupyter (NumPy, SymPy, Matplotlib, Plotly, ipywidgets).
#
# **Indicadores de logro (por objetivo específico)**
#
# 1. **Modelar** una situación real mediante un sistema de la forma $A \mathbf{x} = \mathbf{b}$.
#
#    * Indicador: entrega de una formulación matricial correcta y justificada en al menos 1 problema aplicado (por ejemplo: equilibrio de fuerzas, mezcla de corrientes, ajuste por mínimos cuadrados discretizado).
# 2. **Aplicar** eliminación gaussiana con pivoteo parcial y LU.
#
#    * Indicador: implementación funcional en Python que reproduce la solución de `numpy.linalg.solve` en un 99% de coincidencia (norma relativa del error < $1\times10^{-8}$ para matrices bien condicionadas).
# 3. **Implementar y analizar** métodos iterativos (Jacobi, Gauss–Seidel, Gradiente Conjugado).
#
#    * Indicador: ejecutar pruebas de escritorio y gráficas de convergencia; justificar elección de criterio de paro y tolerancia en 3 ejemplos distintos.
# 4. **Visualizar y experimentar** con condicionamiento y estabilidad numérica.
#
#    * Indicador: producir gráficos interactivos (ipywidgets) que muestren el efecto de la condicionamiento y pivotado sobre la solución.
# 5. **Comunicar** resultados y elección de método justificando eficiencia (complejidad), estabilidad y aplicabilidad.
#
#    * Indicador: informe breve en Jupyter con celdas de explicación, gráficos y resultados reproducibles.
#
# ---
#
# # 3. Mapa conceptual (Graphviz en Python)
#
# A continuación el código que debes ejecutar en tu máquina (VS Code / Jupyter) para generar el mapa conceptual y renderizarlo en `C:/Users/marco/Downloads` con `view=True`. Ajusta si usas otra ruta.
#
# ```python
# # Instala graphviz y python-graphviz si no lo tienes:
# # pip install graphviz
#
# from graphviz import Digraph
#
# g = Digraph('Mapa_Metodos_Lineales', format='png')
# # Controlar overlaps
# g.attr(graph_attr={'overlap':'false'})       # elimina superposiciones
# g.attr(graph_attr={'overlap':'scalexy'})     # escala para evitar overlaps
# g.attr(graph_attr={'overlap':'compress'})    # comprime sin overlaps
#
# # Estilo general
# g.attr('node', style='filled', fontsize='12')
#
# # Nodos principales (formas y colores distintos)
# g.node('Situacion', 'Situación real\n(modelado)', shape='oval', fillcolor='lightgoldenrod1')
# g.node('Modelo', 'Modelo matemático\n$A x = b$', shape='box', fillcolor='lightblue')
# g.node('Directos', 'Métodos directos\n(Gauss, LU)', shape='hexagon', fillcolor='palegreen')
# g.node('Iterativos', 'Métodos iterativos\n(Jacobi, Gauss-Seidel,\nGradiente Conjugado)', shape='ellipse', fillcolor='lightsalmon')
# g.node('Cond', 'Condicionamiento\n& Estabilidad', shape='diamond', fillcolor='lightgrey')
# g.node('Visual', 'Visualizaciones\n& Animaciones', shape='note', fillcolor='lightcyan')
# g.node('Comparacion', 'Comparación\nErrores & Tiempo', shape='box3d', fillcolor='plum')
# g.node('Proyecto', 'Proyecto ABPP\n(Entrega en Jupyter)', shape='folder', fillcolor='thistle')
#
# # Edges
# g.edge('Situacion', 'Modelo', label='Formular')
# g.edge('Modelo', 'Directos', label='Aplicar si A densa\n& tamaño moderado')
# g.edge('Modelo', 'Iterativos', label='Aplicar si A dispersa\no gran tamaño')
# g.edge('Directos', 'Cond', label='Analizar estabilidad')
# g.edge('Iterativos', 'Cond', label='Analizar convergencia')
# g.edge('Directos', 'Comparacion', label='Precisión')
# g.edge('Iterativos', 'Comparacion', label='Convergencia y costo')
# g.edge('Visual', 'Comparacion', label='Mostrar resultados')
# g.edge('Comparacion', 'Proyecto', label='Conclusiones y entrega')
# g.edge('Cond', 'Proyecto', label='Justificación')
#
# # Render en la ruta indicada
# g.render(filename='mapa_metodos_lineales', directory='C:/Users/marco/Downloads', view=True)
# ```
#
# > Nota: `graphviz` debe tener el binario instalado (Graphviz system package). `view=True` abrirá la imagen en tu visor predeterminado.
#
# ---
#
# # 4. Historia y epistemología — contado como cuento (estilo cuentero antioqueño)
#
# *(Incluye imágenes de los protagonistas históricos — aparecen arriba)*
#
# Había una vez, en el pueblo de los números, un muchacho curioso llamado Carl (que la gente conocería como Gauss). Él contaba que cuando niño, sumó y ordenó problemas como quien arregla la cuadra antes de la feria. Un día le dijeron: “Carl, ¿y si los problemas que ves se amontonan y hay que resolverlos todos juntos?” Entonces inventó caminos para ordenar esos montones: la eliminación que hoy lleva su apellido. (Ver imagen de Gauss para recordar su cara severa y amable).
#
# En la esquina de la plaza académica estaba Cauchy, que puso las reglas de la teoría de matrices y de la convergencia —como quien dicta las reglas del mercado— para que los mercaderes (matemáticos) no se enredaran en trucos con decimales y límites. Su nombre quedó pegado a muchos teoremas que garantizan que lo que hacemos en la práctica se parezca a la verdad.
#
# Más tarde vino Arthur Cayley, que le dio a las matrices nombres y apellidos formales —como quien organiza los registros del pueblo— y así las transformaciones y las operaciones entre ellas dejaron de ser misterio.
#
# Y cuando la máquina grande del pueblo —la computadora— empezó a hablar, John von Neumann se sentó en la plaza y dijo: “con esto, podemos pensar en algoritmos que usen las ideas de antes, pero aprovechando nuevas máquinas.” Así nacieron esquemas computacionales para matrices y sistemas grandes.
#
# **Moral del cuento:** el método numérico es el “saber práctico” que nace de ideas teóricas (Álgebra, Análisis) y crece cuando se combina con herramientas (máquinas, algoritmos). Aquí traemos esa tradición al laboratorio de Jupyter: ciencia, técnica y oficio.
#
# ---
#
# # 5. Contenido de la clase (de la situación real al modelo)
#
# **Situación real (problema motivador, inicio invertido):**
# Un pequeño acueducto rural tiene 4 tanques conectados por tuberías. En cada tanque se mide flujo entrante y saliente, y hay restricciones de equilibrio de flujo. Queremos conocer los caudales desconocidos entre tanques (variables). El estudiante recibe los datos y debe modelar el equilibrio como un sistema lineal.
#
# **Del problema al modelo:**
#
# * Identificar incógnitas (caudales entre tanques $x_1,\dots,x_n$).
# * Escribir ecuaciones de balance en cada nodo: suma de flujos entrantes = suma salientes.
# * Reescribir en forma matricial $A \mathbf{x} = \mathbf{b}$ (explica cómo construir $A$ y $\mathbf{b}$).
# * Discutir si $A$ es denso o disperso, simétrica, definida positiva, diagondominante, etc. Esto determina método a aplicar.
#
# **Temas matemáticos y computacionales:**
#
# * Eliminación Gaussiana con pivoteo parcial y absoluto; $O(n^3)$.
# * Descomposición LU (PA=LU), uso para resolver múltiples vectores RHS.
# * Métodos iterativos: Jacobi, Gauss-Seidel, SOR, Gradiente Conjugado (para simétricas definidas positivas).
# * Condicionamiento de $A$, número de condición $\kappa(A)$ y relación con errores relativos: $\frac{|\delta x|}{|x|} \le \kappa(A)\frac{|\delta b|}{|b|}$.
# * Uso de SymPy para ver soluciones simbólicas (pequeñas dimensiones) y NumPy/Scipy para numéricas.
# * Experimentación con ruido en $\mathbf{b}$ y pivotamiento.
#
# ---
#
# # 6. (Salté el número 6 porque la petición original omitió 6 — sigo con 7)
#
# ---
#
# # 7. Actividades de aprendizaje (pruebas de escritorio, pseudocódigo, diagrama de flujo, implementación Python)
#
# ## A. Prueba de escritorio (verbal y paso a paso) — Eliminación Gaussiana
#
# Sistema pequeño:
# $$
# \begin{cases}
# 2x + 3y - z = 5\
# 4x + 4y - 3z = 3\
# -2x + 3y + 2z = 1
# \end{cases}
# $$
#
# **Pasos verbales (prueba de escritorio):**
#
# 1. Escribir la matriz aumentada $[A|b]$.
# 2. Usar $R_2 \leftarrow R_2 - 2 R_1$, $R_3 \leftarrow R_3 + R_1$ para eliminar $x$ en filas 2 y 3.
# 3. Continuar con pivote en segunda columna, eliminar, y realizar sustitución hacia atrás.
#
# (Alumno hace las operaciones numéricas en papel y compara con implementación.)
#
# ## B. Pseudocódigo: Eliminación Gaussiana con pivoteo parcial
#
# ```
# Input: A (n×n), b (n)
# for k in 0..n-2:
#     # pivoteo parcial
#     p = argmax_{i=k..n-1} |A[i,k]|
#     if p != k:
#         swap rows A[k,:] <-> A[p,:]; swap b[k] <-> b[p]
#     # eliminación
#     for i in k+1..n-1:
#         m = A[i,k] / A[k,k]
#         A[i,k] = 0
#         for j in k+1..n-1:
#             A[i,j] = A[i,j] - m * A[k,j]
#         b[i] = b[i] - m * b[k]
# # sustitución hacia atrás
# x = zeros(n)
# for i in n-1..0:
#     s = b[i] - sum_{j=i+1..n-1} A[i,j]*x[j]
#     x[i] = s / A[i,i]
# Return x
# ```
#
# ## C. Diagrama de flujo (descríbetelo; en Jupyter puedes usar `graphviz` o dibujarlo con `matplotlib`):
#
# * Inicio → Lectura A,b → Para k=0..n-2: pivoteo parcial? → Eliminación → Fin ciclo → Sustitución hacia atrás → Resultado → Fin.
#
# (Se puede dibujar con `graphviz.Digraph` o con `matplotlib.patches`; en la clase se pide que los estudiantes creen su propio diagrama para un algoritmo de su elección.)
#
# ## D. Implementación Python: Eliminación Gaussiana con pivoteo parcial (usando NumPy arrays)
#
# ```python
# import numpy as np
#
# def gauss_elimination_pivot(A_in, b_in):
#     A = A_in.astype(float).copy()
#     b = b_in.astype(float).copy()
#     n = A.shape[0]
#     for k in range(n-1):
#         # pivoteo parcial
#         p = np.argmax(np.abs(A[k:, k])) + k
#         if A[p, k] == 0:
#             raise np.linalg.LinAlgError("Matriz singular detectada")
#         if p != k:
#             A[[k, p], :] = A[[p, k], :]
#             b[[k, p]] = b[[p, k]]
#         # eliminación
#         for i in range(k+1, n):
#             m = A[i, k] / A[k, k]
#             A[i, k] = 0.0
#             A[i, k+1:] -= m * A[k, k+1:]
#             b[i] -= m * b[k]
#     # sustitución hacia atrás
#     x = np.zeros(n)
#     for i in range(n-1, -1, -1):
#         s = b[i] - np.dot(A[i, i+1:], x[i+1:])
#         x[i] = s / A[i, i]
#     return x
# ```
#
# **Comparación con NumPy:**
#
# ```python
# x1 = gauss_elimination_pivot(A, b)
# x_np = np.linalg.solve(A_original, b_original)
# rel_error = np.linalg.norm(x1 - x_np) / np.linalg.norm(x_np)
# ```
#
# ## E. Método iterativo: Jacobi (pseudocódigo y Python)
#
# **Pseudocódigo Jacobi**
#
# ```
# x^{(0)} = initial guess
# for k = 0..maxiter:
#     for i = 0..n-1:
#         x_new[i] = (b[i] - sum_{j != i} A[i,j] * x_old[j]) / A[i,i]
#     if ||x_new - x_old|| < tol:
#         break
#     x_old = x_new
# return x_new
# ```
#
# **Python**
#
# ```python
# def jacobi(A, b, x0=None, tol=1e-8, maxiter=1000):
#     n = A.shape[0]
#     if x0 is None:
#         x = np.zeros(n)
#     else:
#         x = x0.copy()
#     D = np.diag(A)
#     R = A - np.diagflat(D)
#     for k in range(maxiter):
#         x_new = (b - R.dot(x)) / D
#         if np.linalg.norm(x_new - x) < tol:
#             return x_new, k+1
#         x = x_new
#     return x, maxiter
# ```
#
# ## F. Gradiente Conjugado (esquema y Python con `numpy`)
#
# ```python
# def conj_grad(A, b, x0=None, tol=1e-8, maxiter=None):
#     n = A.shape[0]
#     if x0 is None:
#         x = np.zeros(n)
#     else:
#         x = x0.copy()
#     r = b - A.dot(x)
#     p = r.copy()
#     rsold = np.dot(r, r)
#     if maxiter is None:
#         maxiter = n
#     for i in range(maxiter):
#         Ap = A.dot(p)
#         alpha = rsold / np.dot(p, Ap)
#         x += alpha * p
#         r -= alpha * Ap
#         rsnew = np.dot(r, r)
#         if np.sqrt(rsnew) < tol:
#             return x, i+1
#         p = r + (rsnew/rsold) * p
#         rsold = rsnew
#     return x, maxiter
# ```
#
# ## G. Visualización de la convergencia (ejemplo con Matplotlib y `ipywidgets`)
#
# ```python
# import matplotlib.pyplot as plt
# import ipywidgets as widgets
# from IPython.display import display, clear_output
#
# # Widget para elegir método y tolerancia
# method_w = widgets.Dropdown(options=['Jacobi','Gauss-Seidel','ConjGrad'], value='Jacobi')
# tol_w = widgets.FloatLogSlider(value=1e-6, base=10, min=-12, max=-2, step=1, description='tol')
# display(method_w, tol_w)
#
# # Al ejecutar, se calcula la historia de errores y se plotea
# ```
#
# ## H. Animación de eliminación paso a paso (matplotlib.animation + IPython.display)
#
# *Recordatorio requerido*: cuando uses `matplotlib.animation` en Jupyter, utiliza `IPython.display.HTML` para renderizar:
#
# ```python
# import matplotlib.animation as animation
# from IPython.display import HTML
#
# fig, ax = plt.subplots()
# # ejemplo simplificado: animar la matriz aumentada durante pasos de eliminación
# def update(frame):
#     ax.clear()
#     # dibujar estado de la matriz en frame
#     ax.imshow(states[frame], interpolation='nearest')
#     ax.set_title(f'Paso {frame}')
# ani = animation.FuncAnimation(fig, update, frames=len(states), interval=800)
# HTML(ani.to_jshtml())  # o HTML(ani.to_html5_video())
# ```
#
# > Siempre incluir `from IPython.display import HTML` o `display`.
#
# ---
#
# # 8. Canción / poema para interiorizar conceptos
#
# **Poema-corrido (rítmico, para tararear en clase)**
#
# > En la plaza del álgebra hay un juego fiel,
# > matrices y vectores, un tango en papel.
# > Pivotea, no te achiques, diagonal brilla más,
# > si el número condiciona, la solución se va.
# >
# > Jacobi camina lento, vecino a vecino va,
# > Gauss–Seidel conversa y más rápido andará.
# > Conjugado, caballero, con paso racional,
# > encuentra en SPD la senda racional.
# >
# > Que el error disminuya, que la tolerancia guíe,
# > y en Jupyter la historia de la solución se escriba.
#
# (Se puede musicalizar con una melodía de tonada antioqueña simple.)
#
# ---
#
# # 9. Tarea / ejercicios de ejercitación y fijación
#
# **Tarea (con entregable en Jupyter Notebook):**
#
# 1. Modela el problema del acueducto (4 tanques) y construye $A$ y $b$. Resuelve con `np.linalg.solve` y con tu función `gauss_elimination_pivot`. Informe: compara tiempos y errores.
# 2. Implementa Jacobi y Gauss–Seidel; compara convergencia en tres matrices: diagonal dominante, mal condicionada y dispersa (sparse). Grafica las normas residuales por iteración (usar `matplotlib`).
# 3. Implementa Gradiente Conjugado y úsalo en una matriz SPD grande (por ejemplo, matriz de Laplace 50×50). Muestra animación de la disminución del residual.
# 4. Experimento de condicionamiento: crea matrices con condición creciente (modificando singular values con `numpy.linalg.svd`) y muestra la relación error/perturbación.
# 5. (Opcional) Uso de `SymPy`: resolver un sistema simbólico 2×2 y comparar con solución numérica.
#
# ---
#
# # 10. Evaluación
#
# ## A. Diez ideas de proyectos (ABPP / STEAMS)
#
# 1. **Proyecto 1:** Modelado y solución del sistema de equilibrio de una red de agua (acueducto) — reporte y Jupyter interactivo.
# 2. **Proyecto 2:** Simulación de nodos eléctricos (red resistiva) y solución de corrientes con métodos iterativos (visualización dinámica).
# 3. **Proyecto 3:** Implementación de un solver paralelizable (concepto) y análisis de tiempo (simular con matrices grandes).
# 4. **Proyecto 4:** Aplicación: ajuste de datos por mínimos cuadrados (normal equations vs QR) para una señal experimental.
# 5. **Proyecto 5:** Estudio del condicionamiento numérico en problemas de geodesia (pequeño dataset).
# 6. **Proyecto 6:** Reconstrucción de una imagen mediante solución de un sistema lineal (p. ej. deblur) usando métodos iterativos.
# 7. **Proyecto 7:** Construcción de un paquete didáctico en Jupyter con widgets que enseñe la eliminación paso a paso.
# 8. **Proyecto 8:** Comparación de bibliotecas (NumPy vs SciPy) en precisión y rendimiento para problemas reales.
# 9. **Proyecto 9:** Uso de gradiente conjugado para resolver PDE discretizadas (ej. difusión) y visualización con `plotly`.
# 10. **Proyecto 10:** Diseño de una actividad STEAM: montar un experimento físico (pequeña red de tanques o circuito), medir y resolver con métodos numéricos.
#
# ## B. Ejemplo de quiz (10 min, autoevaluación)
#
# **Pregunta de ejemplo (multiple choice):**
# Si $A$ es estrictamente diagonal dominante por filas, entonces:
# A) El método de Jacobi converge para cualquier vector inicial.
# B) La eliminación gaussiana no necesita pivoteo.
# C) $A$ siempre es SPD.
# D) Ninguna de las anteriores.
#
# **Respuesta correcta:** A (justificación breve en el notebook).
#
# ## C. Ejemplo de parcial (duración 90 min — 2 problemas)
#
# **Parcial (2 problemas)**
#
# **Problema 1 (60 puntos):**
# Dado el sistema
# $$
# \begin{pmatrix}
# 10 & -1 & 2 & 0\
# -1 & 11 & -1 & 3\
# 2 & -1 & 10 & -1\
# 0 & 3 & -1 & 8
# \end{pmatrix} x = \begin{pmatrix}6\25\-11\15\end{pmatrix}
# $$
# a) Realice la eliminación gaussiana con pivoteo parcial (anote pasos y matriz aumentada). (30 pts)
# b) Implementar en Python su algoritmo y comparar con `np.linalg.solve`. Reporte la norma relativa del error. (20 pts)
# c) ¿La matriz es diagonalmente dominante? ¿Qué implicaciones tiene para Jacobi/Gauss-Seidel? (10 pts)
#
# **Problema 2 (40 puntos):**
# a) Implementar Jacobi y Gradiente Conjugado; pruebe en una matriz SPD de 100×100 (por ejemplo la matriz de Laplace) y muestre un gráfico de la norma del residual vs iteración. (25 pts)
# b) Explique brevemente (5–7 renglones) cuándo elegiría con qué método en problemas reales. (15 pts)
#
# ---
#
# # 11. Diseño de actividad de retroalimentación
#
# **Dinámica (30–40 min):**
#
# 1. **Auto-evaluación breve:** cada estudiante corre su notebook y responde 3 preguntas de auto-chequeo (resultado numérico, gráfico, interpretación).
# 2. **Peer review (pares):** intercambio de notebooks (3 porciones de la clase) — cada par revisa: modelado correcto, método aplicado justificadamente, visualizaciones claras. Cada revisión debe incluir 3 sugerencias: 2 buenas prácticas y 1 mejora.
# 3. **Retroalimentación del profe:** en una sesión síncrona corta se comentan patrones comunes (p. ej. mala elección de tolerancia, matrices mal construidas) y se ejemplifica corrección en vivo sobre uno o dos notebooks.
# 4. **Cierre:** entrega de una versión corregida del notebook (entrega final) con un bloque de reflexión corto (qué aprendí y qué mejoraría).
#
# ---
#
# # 12. Vocabulario y frases en inglés (útil para documentación y lectura de papers)
#
# **Vocabulario (palabra — traducción breve):**
#
# * Matrix — matriz
# * Linear system — sistema lineal
# * Pivoting — pivoteo
# * Gaussian elimination — eliminación gaussiana
# * LU decomposition — descomposición LU
# * Iterative method — método iterativo
# * Convergence — convergencia
# * Residual — residual
# * Conditioning — condicionamiento
# * Sparse matrix — matriz dispersa (sparse)
# * Diagonally dominant — diagonalmente dominante
# * Symmetric positive definite (SPD) — simétrica definida positiva
#
# **Frases útiles:**
#
# * "We solve the linear system $A x = b$" — “Resolvemos el sistema lineal $A x = b$”.
# * "Use partial pivoting to improve numerical stability." — “Usar pivoteo parcial para mejorar la estabilidad numérica.”
# * "The method converges if the spectral radius is less than one." — “El método converge si el radio espectral es menor que uno.”
# * "Compute the condition number using `np.linalg.cond(A)`." — “Calcule el número de condición con `np.linalg.cond(A)`.”
#
# ---
#
# # 13. Apéndice: desarrollo de habilidades blandas y inteligencia emocional
#
# **Objetivo:** promover trabajo en equipo, asertividad, empatía y conducta ética ante evaluaciones.
#
# **A. Habilidades para trabajo en equipo**
#
# * Formar equipos de 3–4 personas con roles rotativos: líder técnico (codifica), documentador (escribe notebook), verificador (prueba y valida).
# * Actividad: cada equipo produce un checklist de buenas prácticas (nombres de variables, documentación de celdas, tests unitarios simples).
#
# **B. Asertividad y empatía**
#
# * Mini-taller (30 min): role-play de retroalimentación: un miembro explica su implementación; otro ofrece crítica constructiva usando la fórmula: "Primero un elogio, luego la observación concreta, y finalmente una sugerencia".
# * Indicador: cada estudiante debe dar al menos 2 retroalimentaciones constructivas por sesión.
#
# **C. Inteligencia emocional para presentar pruebas sin temor**
#
# * Técnica breve de respiración 4-4-4 antes del parcial.
# * Reglas de evaluación clara: rubrica publicada previamente para evitar ansiedad.
# * Políticas de integridad académica: explicar consecuencias de fraude y proponer alternativas (revisión formativa, resubmission) para que no recurran a copia.
#
# **D. Actividades para desarrollar tolerancia**
#
# * Rotaciones de equipo: cada 3 clases, cambiar miembros; refleja diversidad de enfoques.
# * Ejercicio: resolver un problema con dos métodos (directo e iterativo) y escribir una síntesis de 100 palabras explicando por qué cada método fue útil.
#
# ---
#
# # 14. Referentes en didáctica de la matemática (ordenados en APA)
#
# Incluyo 5 referentes que se alinean con la propuesta (Aula Invertida, STEAMS, ABPP), añadiendo a Raymond Duval y Jeannette Wing como pediste. (Los siguientes son referencias sugeridas en formato APA; verifica en tu gestor bibliográfico la última edición/ISBN si necesitas enlazar o descargar.)
#
# 1. Bergmann, J., & Sams, A. (2012). *Flip Your Classroom: Reach Every Student in Every Class Every Day*. International Society for Technology in Education.
#
#    * (Fundamenta el uso del Enfoque de Aula Invertida).
#
# 2. Yakman, G. (2008). *STEM and the Art of Innovation*. (Paper / capítulo).
#
#    * (Fundamento conceptual del enfoque STEAM/STEAMS — integrar artes en STEM).
#
# 3. Hmelo-Silver, C. E. (2004). Problem-Based Learning: What and How Do Students Learn? *Educational Psychology Review*, 16(3), 235–266.
#
#    * (Fundamento del Aprendizaje Basado en Problemas y Proyectos — ABPP).
#
# 4. Duval, R. (1995). *Representaciones semióticas y aprendizaje de las matemáticas* (traducción y revisión). (Original en francés).
#
#    * (Sobre representaciones y cambios de representación para la adquisición de conceptos matemáticos).
#
# 5. Wing, J. M. (2006). Computational Thinking. *Communications of the ACM*, 49(3), 33–35.
#
#    * (Sobre el desarrollo del pensamiento computacional, central en usar Jupyter y programación como herramienta didáctica).
#
# **(Adicionales sugeridos que apoyan la didáctica en ambientes digitales y PBL)**
# 6. Prince, M. (2004). Does Active Learning Work? A Review of the Research. *Journal of Engineering Education*, 93(3), 223–231.
# 7. Jonassen, D. H. (1999). *Designing Constructivist Learning Environments*. In C. M. Reigeluth (Ed.), *Instructional-design Theories and Models*.
#
# > *Nota:* si deseas, preparo las referencias con DOI y enlaces para que las incluyas en tu bibliografía.
#
# ---
#
# ## Observaciones técnicas y recomendaciones para Jupyter / VS Code
#
# * **Import inicial recomendado (como indicaste):**

# %%
```python
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML
from matplotlib.patches import Rectangle
import seaborn as sns
import pandas as pd
import sympy as sp
import plotly.graph_objects as go
import matplotlib.animation as animation
```

# %% [markdown]
# * **Matplotlib animation:** siempre renderizar con `HTML(ani.to_jshtml())` o `HTML(ani.to_html5_video())` (dependiendo del entorno).
# * **ipywidgets en VS Code:** usar `display()` para asegurarse que el widget aparezca; en algunos casos es necesario habilitar la extensión de Jupyter en VS Code.
# * **Uso de SymPy:** útil para validación simbólica en problemas pequeños; convertir matrices `sp.Matrix` a `numpy` cuando se requiera velocidad.
#
# ---
#
# ## Breve resumen de lo entregado (para que lo copies en tu repositorio)
#
# * Diseño de clase completo con objetivos e indicadores.
# * Código Graphviz listo para renderizar en `C:/Users/marco/Downloads` con `view=True`.
# * Historia-epistemología en estilo cuentero antioqueño + imágenes de protagonistas.
# * Contenido desde situación real → modelo matemático.
# * Pruebas de escritorio, pseudocódigo, diagrama de flujo descriptivo.
# * Implementaciones Python (Gauss, Jacobi, CG) y notas de visualización y animación en Jupyter.
# * Poema, tareas, 10 proyectos, ejemplo de quiz y parcial, y actividad de retroalimentación.
# * Vocabulario inglés y apéndice de habilidades blandas.
# * Referencias APA (incluyen Duval y Wing).
#
# ---
#
# Si quieres, ahora puedo:
#
# * Generar y adjuntar un **notebook de ejemplo (.ipynb)** que contenga: el modelo del acueducto, implementaciones (Gauss, Jacobi, CG), widgets interactivos y una animación de eliminación (listo para ejecutar en tu VS Code).
# * Preparar la versión en *Markdown* o un archivo `README.md` listo para tu repositorio GitHub.
#
# Dime cuál prefieres y te lo genero inmediatamente en formato ejecutable (notebook) con celdas listas para correr en Jupyter / VS Code.

# %% [markdown]
# # Calendario Académico
#
# * Clase de Análisis Numérico: Viernes de 8 a 12 M.
# * Terminación de clases: 22 de noviembre de 2025
# * Exámenes finales: 24 al 29 de noviembre de 2025
# * Habilitación y validación: 01 al 06 de diciembre 2025
# * Terminación oficial del semestre: 09 de diciembre de 2025.

# %% [markdown]
# # Cursos que orienta el profesor Marco Julio Cañas Campillo en 2025
#
# 4. Fundamentos de Lógica para Licenciatura en Matemáticas. Lunes de 8 a 12.
# 5. Álgebra y Trigonometría para Matemáticas: Martes de 9 a 11.
# 6. Fundamentos de Lógica para Licenciatura en Matemáticas
# 7. Análisis Numérico para Licenciatura en Matemáticas: Viernes de 8 a 12.

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12: Fundamentos de Lógica.
# * Martes 9-11 M: Álgebra y Trigonometría.
# * Martes 2 a 6 PM: Geometría Vectorial y Analítica
# * Miércoles 9 a 11 M: Álgebra y Trigonometría.
# * Jueves 2 a 6 PM: Desarrollo del pensamiento matemático en la infancia.
# * Viernes 8 - 12 M: Análisis Numérico.
# * Sábados 8-12 Asesorías y espacio para retroalimentación y apoyo al trabajo independiente.

# %% [markdown]
# # Horarios de monitoría y asesoría
#
# * Asesoría: Sábados de 8 a 12 en el aula que nos asigne la sección de medios y logística.

# %% [markdown]
# # Coordinador de los cursos de la Facultad de Educación para regiones:
#
# Andrés Vélez: regioneducacion.fedu@udea.edu.co
# Coordinador Regiones
# Facultad de Educación
# Universidad de Antioquia

# %% [markdown]
# ## Monitores
# * José Luis Guerrero Guerra: .
# *

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Bergmann, J. (2012). *Flip Your Classroom.* (Aula Invertida).](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://blogs.ugto.mx/mdued/wp-content/uploads/sites/66/2022/11/Bergmann-y-Sams-Dale-la-vuelta-a-tu-clase.pdf)
#
# * [CALCULO I DE UNA VARIABLE Ron Larson-Bruce Edwards. Mc Graw Hill. 9º Edición](https://www.academia.edu/42139251/CALCULO_I_DE_UNA_VARIABLE_Ron_Larson_Bruce_Edwards_Mc_Graw_Hill_9o_Edici%C3%B3n)
#
# * [Métodos numéricos usando python](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://librosoa.unam.mx/bitstream/handle/123456789/3416/MNPython.pdf?sequence=1&isAllowed=y)
#
# * [Métodos numéricos usando python. Código fuente de todo el libro](https://github.com/jcjimenezb123/MNPython-Libro?tab=readme-ov-file#readme)
#
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://bibliotecadigital.udea.edu.co/handle/10495/3010)
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://tanthiamhuat.wordpress.com/wp-content/uploads/2018/03/deeplearningwithpython.pdf)
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)
#
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)
#
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
#
#
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Clase de análisis numérico los Viernes de 8 a 12 del medio día.

# %% [markdown]
# # Fundamentar Pedagógica y didácticamente mi propuesta de enseñanza
#
# ## Prompt
#
# Dame referentes en didáctica de las matemáticas que sustente mi creencia y perspectiva que piensa que el desarrollo del pensamiento computacional debe fomentarse desde todos los niveles de escolaridad, más aún en educación superior con el animo de desarrollar la capacidad de leer de manera interactiva y experimental y así, con los cuadernos Jupyter, la enseñanza de los lenguajes Latex, MarkDown, Python e inglés, aportar al desarrollo de los profesionales de nuestra Universidad sin rivalizar con la postura de enseñanza que piensa que es inadecuado presentar paralelamente en la enseñanza de las matemáticas, los lenguajes que menciono, que creo pueden contribuir al aprendizaje de una matemática de manera significativa, y más cercana a lo que la empresa privada y pública requiere de nuestros egresados.

# %% [markdown]
# Mi planteamiento tiene mucho sustento en la **didáctica de las matemáticas contemporánea** y en corrientes relacionadas con el **pensamiento computacional, la alfabetización digital y el aprendizaje significativo**. Estos son referentes y marcos conceptuales que pueden servir para  citar o usar y fortalecer mi perspectiva:
#
# ---

# %% [markdown]
# # Referentes en Didáctica de las Matemáticas y Pensamiento Computacional
#
# ### 1. **Seymour Papert (1980, 1996)**
#
# * Padre del **constructionism**, con su obra *Mindstorms* (1980).
# * Plantea que la computadora no es solo una herramienta de cálculo, sino un **medio para pensar** y construir conocimiento matemático.
# * Sostiene que programar permite a los estudiantes interactuar con conceptos matemáticos de manera experimental.
# * Su lema central: *“Los niños no aprenden la matemática de las computadoras; aprenden matemáticas con las computadoras”*.
#   👉 Esto respalda tu idea de usar Python, LaTeX y Markdown como lenguajes que median la construcción de significados matemáticos.
#
# ---

# %% [markdown]
# ### 2. **Alan H. Schoenfeld (1985, 1992)**
#
# * Destaca la importancia de la **resolución de problemas** en la enseñanza de las matemáticas.
# * Su enfoque conecta con la idea de que el pensamiento computacional fomenta la **formulación, exploración y verificación de conjeturas** en ambientes como Jupyter Notebooks.
#   👉 Schoenfeld da soporte a que los lenguajes que propones sean **recursos didácticos** para generar entornos de resolución activa.
#
# ---

# %% [markdown]
# ### 3. **Jean Piaget & Lev Vygotsky (constructivismo y socio-constructivismo)**
#
# * Piaget: El conocimiento se construye a través de la acción y la experimentación.
# * Vygotsky: El aprendizaje se potencia con herramientas culturales y mediaciones.
#   👉 Jupyter, Python, LaTeX e inglés son **herramientas culturales del siglo XXI** que median el aprendizaje matemático.
#
# ---
#
# ### 4. **Wing, Jeannette (2006)**
#
# * Introduce el término **pensamiento computacional** como una habilidad básica, tan fundamental como leer, escribir o hacer matemáticas.
# * Define que debe enseñarse desde la escuela hasta la universidad.
#   👉 Tu planteamiento de aplicarlo en **todos los niveles** y en **educación superior** tiene un sustento directo aquí.
#
# ---
#
# ### 5. **NCTM (National Council of Teachers of Mathematics, 2000, 2014)**
#
# * En sus principios y estándares, plantea la necesidad de que los estudiantes desarrollen **fluidez tecnológica** en paralelo con la matemática.
# * Afirma que las herramientas tecnológicas permiten experimentar, representar y validar conceptos de manera más profunda.
#   👉 Esto legitima tu postura de que **no se trata de rivalizar con la enseñanza tradicional**, sino de enriquecerla con recursos.
#
# ---
#
# ### 6. **Duval, Raymond (1993, 2006)**
#
# * Con su teoría de los **registros de representación semiótica**, muestra que el aprendizaje matemático se fortalece cuando los estudiantes pueden cambiar entre registros (gráfico, simbólico, numérico, verbal, digital).
#   👉 Los lenguajes LaTeX, Markdown y Python son **nuevos registros de representación**, que complementan y no sustituyen al registro algebraico tradicional.
#
# ---
#
# ### 7. **Godino, Juan D. y el Enfoque Ontosemiótico (EOS)**
#
# * Plantea que la matemática se aprende a través de **configuraciones de prácticas y significados**.
# * El uso de Jupyter y lenguajes computacionales enriquece esas prácticas al incluir **experimentación, validación y comunicación científica**.
#   👉 Esto refuerza tu idea de que estos lenguajes no compiten, sino que **aportan a la construcción de significados matemáticos más cercanos al mundo profesional**.
#
# ---
#
# ### 8. **Sociedades Matemáticas y Computacionales**
#
# * **ACM (Association for Computing Machinery)** y **IEEE** han publicado directrices donde destacan que el pensamiento computacional debe ser transversal a todas las disciplinas.
# * En Latinoamérica, la **Sociedad Colombiana de Matemáticas Educativa (ASOCOLME)** también promueve la integración de tecnologías en la didáctica.
#
# ---

# %% [markdown]
# # Cómo integrar estos referentes con tu postura
#
# 1. **Papert, Wing y Piaget-Vygotsky** sustentan que el pensamiento computacional debe enseñarse desde todos los niveles.
# 2. **Schoenfeld, Duval y Godino** muestran que estas herramientas enriquecen la comprensión matemática sin sustituir los enfoques tradicionales.
# 3. **NCTM, ACM y IEEE** legitiman que las matemáticas deben enseñarse con herramientas tecnológicas alineadas con el mundo laboral y científico.
#
# ---

# %% [markdown]
# # Frase integradora que puedes usar
#
# > “Siguiendo a Papert, Wing y Duval, concebimos el pensamiento computacional no como un accesorio, sino como un lenguaje cultural contemporáneo. Al incorporar Python, LaTeX, Markdown e inglés en la enseñanza de las matemáticas mediante entornos como Jupyter Notebooks, no competimos con los métodos tradicionales, sino que ampliamos los registros de representación y potenciamos el aprendizaje significativo, en sintonía con lo que requieren los profesionales del siglo XXI.”
#
# ---
#
# ¿Quieres que te arme una **línea argumentativa redactada como marco teórico** (listo para tu artículo o propuesta), o prefieres que primero te organice una **tabla de referentes con citas clave** para que los tengas como insumo rápido?

# %% [markdown]
# Esta es una **línea argumentativa** como marco teórico (redacción académica), y una **tabla de referentes con citas clave** para respaldar la bibliografía.
#
# ---

# %% [markdown]
# # Línea argumentativa (Marco teórico)
#
# El desarrollo del **pensamiento computacional** constituye hoy un eje fundamental en la educación matemática. Como lo plantea **Wing (2006)**, esta forma de razonamiento debe considerarse una competencia transversal y básica, al nivel de la lectura, la escritura y las matemáticas. En consecuencia, fomentar su aprendizaje desde los niveles iniciales hasta la educación superior resulta indispensable para formar profesionales capaces de enfrentar los retos de la sociedad contemporánea.
#
# En el campo de la didáctica de las matemáticas, **Papert (1980, 1996)** había anticipado esta necesidad al concebir las computadoras no como simples herramientas de cálculo, sino como **“objetos para pensar”**, capaces de favorecer la construcción activa de significados matemáticos a través de la programación. Esta visión se alinea con el constructivismo de **Piaget**, que resalta el valor de la experimentación en el aprendizaje, y con la perspectiva socio-constructivista de **Vygotsky**, que otorga un papel central a las herramientas culturales en la mediación del conocimiento.
#
# En este marco, el uso de entornos como **Jupyter Notebooks** y lenguajes como **Python, LaTeX, Markdown e inglés** no debe interpretarse como una rivalidad con la enseñanza tradicional de la matemática, sino como una **ampliación de los registros de representación** que describió **Duval (1993, 2006)**. Según su teoría semiótica, el aprendizaje significativo se potencia cuando el estudiante logra traducir y articular distintos sistemas de representación: gráfico, algebraico, numérico, verbal y, en nuestro tiempo, digital.
#
# De igual manera, el **Enfoque Ontosemiótico de Godino (2002, 2017)** muestra que los significados matemáticos emergen de prácticas diversas, lo que justifica la incorporación de estos lenguajes como recursos que enriquecen las configuraciones de práctica matemática, en sintonía con las exigencias de la investigación y la práctica profesional.
#
# En el ámbito internacional, organizaciones como el **NCTM (2000, 2014)** han subrayado que la tecnología es esencial para la enseñanza y el aprendizaje de la matemática, dado que facilita la experimentación, la validación de conjeturas y la comunicación de ideas. Asimismo, instancias como la **ACM** y el **IEEE** han señalado la importancia de desarrollar habilidades computacionales como requisito fundamental en la formación universitaria, tanto en el sector público como privado.
#
# Por tanto, enseñar matemáticas integrando Python, LaTeX, Markdown e inglés en ambientes como Jupyter Notebooks contribuye a la formación de profesionales con **competencias científicas, comunicativas y tecnológicas**, capaces de comprender la matemática de manera interactiva y experimental, y de responder a las demandas del mundo laboral. Esta integración, lejos de ser inadecuada, constituye un **puente entre la enseñanza académica y las necesidades de la sociedad**, fortaleciendo la pertinencia de los programas universitarios.
#
# ---

# %% [markdown]
# # Tabla de referentes en didáctica de las matemáticas y pensamiento computacional
#
# | **Autor / Institución**         | **Aporte central**                                                                       | **Relevancia para tu postura**                                                            |
# | ------------------------------- | ---------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------- |
# | **Papert, S. (1980, 1996)**     | *Mindstorms*. La computadora como “objeto para pensar”; base del constructionism.        | Justifica la programación (Python) como medio para construir conocimiento matemático.     |
# | **Wing, J. (2006)**             | Introduce el concepto de **pensamiento computacional** como habilidad básica para todos. | Fundamenta que debe enseñarse desde la primaria hasta la universidad.                     |
# | **Schoenfeld, A. (1985, 1992)** | Enfoque en la **resolución de problemas** y procesos cognitivos en matemáticas.          | Apoya el uso de herramientas digitales para explorar y verificar conjeturas.              |
# | **Piaget, J.**                  | Constructivismo: el aprendizaje surge de la acción y la experimentación.                 | Refuerza la idea de aprender matemáticas de forma interactiva en Jupyter.                 |
# | **Vygotsky, L.**                | Socio-constructivismo: las herramientas culturales median el aprendizaje.                | Python, LaTeX y Markdown son **herramientas culturales contemporáneas**.                  |
# | **Duval, R. (1993, 2006)**      | Teoría de registros de representación semiótica.                                         | LaTeX, Markdown y Python son nuevos registros que enriquecen la comprensión matemática.   |
# | **Godino, J. D. (2002, 2017)**  | Enfoque Ontosemiótico de la Cognición Matemática.                                        | Los lenguajes digitales enriquecen las configuraciones de práctica matemática.            |
# | **NCTM (2000, 2014)**           | Principios y estándares: la tecnología es esencial en matemáticas.                       | Legitima el uso de Jupyter y lenguajes como recursos para experimentación y comunicación. |
# | **ACM / IEEE**                  | Lineamientos de competencias digitales y computacionales en educación superior.          | Respaldo internacional: el mercado laboral exige habilidades computacionales.             |
#
# ---

# %% [markdown]
# # Referencias en formato APA (7ª edición)
#
# * ACM & IEEE Computer Society. (2013). *Computer Science Curricula 2013: Curriculum Guidelines for Undergraduate Degree Programs in Computer Science*. ACM Press. [https://doi.org/10.1145/2534860](https://doi.org/10.1145/2534860)
#
# * Duval, R. (1993). *Registres de représentations sémiotiques et fonctionnement cognitif de la pensée*. Annales de didactique et de sciences cognitives, 5, 37–65.
#
# * Duval, R. (2006). A cognitive analysis of problems of comprehension in a learning of mathematics. *Educational Studies in Mathematics, 61*(1-2), 103–131. [https://doi.org/10.1007/s10649-006-0400-z](https://doi.org/10.1007/s10649-006-0400-z)
#
# * Godino, J. D., Batanero, C., & Font, V. (2007). The onto-semiotic approach to research in mathematics education. *ZDM Mathematics Education, 39*(1–2), 127–135. [https://doi.org/10.1007/s11858-006-0004-1](https://doi.org/10.1007/s11858-006-0004-1)
#
# * Godino, J. D. (2017). El enfoque ontosemiótico de la cognición e instrucción matemática. *Revista Latinoamericana de Investigación en Matemática Educativa, 20*(1), 5–30. [https://doi.org/10.12802/relime.17.2011](https://doi.org/10.12802/relime.17.2011)
#
# * National Council of Teachers of Mathematics. (2000). *Principles and Standards for School Mathematics*. Reston, VA: NCTM.
#
# * National Council of Teachers of Mathematics. (2014). *Principles to Actions: Ensuring Mathematical Success for All*. Reston, VA: NCTM.
#
# * Papert, S. (1980). *Mindstorms: Children, Computers, and Powerful Ideas*. New York, NY: Basic Books.
#
# * Papert, S. (1996). *The Connected Family: Bridging the Digital Generation Gap*. Atlanta, GA: Longstreet Press.
#
# * Piaget, J. (1970). *Psychology and Epistemology: Towards a Theory of Knowledge*. New York, NY: Viking Press.
#
# * Schoenfeld, A. H. (1985). *Mathematical Problem Solving*. Orlando, FL: Academic Press.
#
# * Schoenfeld, A. H. (1992). Learning to think mathematically: Problem solving, metacognition, and sense-making in mathematics. In D. Grouws (Ed.), *Handbook of Research on Mathematics Teaching and Learning* (pp. 334–370). New York, NY: Macmillan.
#
# * Vygotsky, L. S. (1978). *Mind in Society: The Development of Higher Psychological Processes*. Cambridge, MA: Harvard University Press.
#
# * Wing, J. M. (2006). Computational thinking. *Communications of the ACM, 49*(3), 33–35. [https://doi.org/10.1145/1118178.1118215](https://doi.org/10.1145/1118178.1118215)
#
# ---

# %% [markdown]
# Con estas referencias ya tienes un **marco bibliográfico sólido y reconocido internacionalmente**, que respalda tu propuesta de fomentar el pensamiento computacional y el uso de lenguajes (Python, LaTeX, Markdown, inglés) en la enseñanza de las matemáticas en tu universidad.

# %% [markdown]
# #  Estado del arte
#
# El interés por integrar la tecnología en la enseñanza de las matemáticas tiene raíces en las propuestas de **Papert (1980, 1996)**, quien con su enfoque constructionista concibió la computadora como un “objeto para pensar”, capaz de mediar la construcción activa de significados matemáticos mediante la programación. Esta perspectiva se enlaza con los planteamientos de **Piaget (1970)** y **Vygotsky (1978)**, quienes reconocieron la importancia de la experimentación y de las herramientas culturales en la formación del pensamiento. Bajo esta mirada, el uso de entornos digitales no constituye una amenaza para la enseñanza tradicional de las matemáticas, sino un recurso que amplía las posibilidades de aprendizaje.
#
# A comienzos del siglo XXI, la noción de **pensamiento computacional** introducida por **Wing (2006)** renovó el debate al proponer que esta competencia debía enseñarse de manera transversal desde los niveles iniciales hasta la educación superior, situándola al mismo nivel que la lectura, la escritura y las matemáticas. Este enfoque se alinea con los planteamientos del **NCTM (2000, 2014)**, que destacó la tecnología como un componente esencial para la experimentación, la representación y la comunicación en matemáticas. En paralelo, aportes teóricos como la **teoría de registros de representación semiótica de Duval (1993, 2006)** y el **Enfoque Ontosemiótico de Godino (2007, 2017)** muestran que el aprendizaje matemático se enriquece al transitar entre múltiples sistemas de representación, incluyendo los digitales.
#
# En el contexto actual, organizaciones como la **ACM** y el **IEEE** insisten en que las competencias computacionales son indispensables en la formación profesional, lo que refuerza la pertinencia de integrar lenguajes como **Python, LaTeX, Markdown e inglés** en ambientes como **Jupyter Notebooks** para la enseñanza universitaria de las matemáticas. Así, el estado del arte evidencia un consenso creciente: lejos de ser un obstáculo, el pensamiento computacional y el uso de lenguajes digitales constituyen una vía para fortalecer la comprensión matemática, formar profesionales más competentes y responder a las demandas del mundo laboral y científico contemporáneo.
#
# ---

# %% [markdown]
# # Estado del arte con citas
#
# El uso de la tecnología en la enseñanza de las matemáticas encuentra uno de sus pilares en **Papert (1980)**, quien afirmaba que *“los niños no aprenden sobre la computadora, aprenden con la computadora”* (p. 6). En su visión, la programación se convierte en un medio para la construcción activa de significados matemáticos, idea que se enlaza con la epistemología genética de **Piaget (1970)**, quien sostuvo que *“el conocimiento se construye a través de la acción”* (p. 15), y con la perspectiva de **Vygotsky (1978)**, al señalar que *“toda función en el desarrollo cultural del niño aparece dos veces: primero en el plano social y después en el individual”* (p. 57). Estos enfoques coinciden en otorgar a las herramientas culturales un papel esencial en la mediación del aprendizaje.
#
# Posteriormente, **Wing (2006)** acuñó el término pensamiento computacional, definiéndolo como *“una habilidad fundamental para todos, no solo para los científicos de la computación”* (p. 33). Esta autora subrayó que debía enseñarse de manera transversal, en paralelo con la lectura, la escritura y la matemática. En la misma línea, el **NCTM (2000)** destacó que *“la tecnología es esencial en la enseñanza y el aprendizaje de las matemáticas; influye en la matemática que se enseña y mejora el aprendizaje de los estudiantes”* (p. 24).
#
# Desde la didáctica de las matemáticas, **Duval (2006)** mostró que *“la comprensión matemática requiere la coordinación de al menos dos registros de representación diferentes”* (p. 107), lo que legitima la incorporación de registros digitales como LaTeX, Markdown y Python. Por su parte, **Godino (2017)** planteó que *“el significado de un objeto matemático está constituido por el sistema de prácticas en el que interviene”* (p. 7), con lo cual la práctica digital se convierte en parte constitutiva del aprendizaje matemático.
#
# Finalmente, organismos internacionales como la **ACM y el IEEE (2013)** enfatizan que *“las habilidades computacionales son esenciales para el ejercicio profesional en cualquier disciplina”* (p. 12). De esta manera, se consolida un consenso: la enseñanza universitaria de las matemáticas debe integrar herramientas contemporáneas como **Jupyter Notebooks, Python, LaTeX, Markdown e inglés**, no para competir con la enseñanza tradicional, sino para **fortalecer la comprensión matemática, potenciar la comunicación científica y responder a las demandas del mundo laboral**.
#
# ---
