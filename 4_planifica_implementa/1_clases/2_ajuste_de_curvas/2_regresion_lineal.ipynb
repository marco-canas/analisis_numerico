# %%
import numpy as np 
from scipy import stats 
import matplotlib.pyplot as plt

# %%
# Aquí estamos ingresando los datos 
y = np.array([6,9,11,13,22,26,28,33,35])
x = np.array([68,67,65,53,44,40,37,34,32])

# %%
m, b, r, p, std_err = stats.linregress(x, y)

# %%
m
# Out:
# np.float64(-0.7238507231404959)

# %%
b
# Out:
# np.float64(55.72159090909091)

# %%
r
# Out:
# np.float64(-0.9773259508767143)

# %%
print('Intersecto con el eje y ', b)
print('pendiente ', m)
print('coeficiente de correlacion ', r)
# Out:
# Intersecto con el eje y  55.72159090909091
# pendiente  -0.7238507231404959
# coeficiente de correlacion  -0.9773259508767143

# %%
 y_pred = m*x+b

# %%
y_pred
# Out:
# array([ 6.49974174,  7.22359246,  8.6712939 , 17.35750258, 23.87215909,
#        26.76756198, 28.93911415, 31.11066632, 32.55836777])

# %%
plt.plot(x,y,'o', label='Datos')
plt.plot(x,y_pred,'r:',label='Regresion lineal')

plt.title('Deformacion y Dureza')
plt.xlabel('Dureza')
plt.ylabel('Deformacion')
# Out:
# Text(0, 0.5, 'Deformacion')
