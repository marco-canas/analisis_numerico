# %% [markdown]
# # Retroalimentación del parcial 1
#
# Te doy ejemplos de **funciones o modelos matemáticos en contextos agropecuarios, físicos (cinemática) y de ciencias económicas** donde es útil aplicar el **método de Newton–Raphson** para encontrar raíces:
#
# ---
#
# ## 🔹 1. Contextos **Agropecuarios**
#
# En agricultura y ganadería, los modelos de crecimiento o de optimización de recursos suelen ser **no lineales**.
#
# **Ejemplo 1 – Crecimiento logístico de una población animal o cultivo**
# El modelo logístico es:
#
# $$
# f(P) = P - \frac{K}{1 + A e^{-rt}}
# $$
#
# Si queremos estimar el **tiempo $t$** en que la población $P$ alcanza un valor específico (por ejemplo, el 80% de la capacidad de carga $K$), hay que resolver:
#
# $$
# f(t) = \frac{K}{1 + A e^{-rt}} - P = 0
# $$
#
# Este se resuelve con Newton–Raphson porque la ecuación no es lineal en $t$.
#
# **Ejemplo 2 – Producción agrícola con ley de rendimientos decrecientes**
# Una función de producción de tipo **Cobb–Douglas**:
#
# $$
# Q(F) = aF^b
# $$
#
# donde $Q$ es el rendimiento y $F$ es la cantidad de fertilizante.
# Si queremos encontrar el nivel de fertilizante $F$ que maximiza la diferencia entre el beneficio y el costo, debemos resolver:
#
# $$
# f(F) = a b F^{b-1} - C = 0
# $$
#
# (lo que surge de la condición de óptimo: $Q'(F) = C$).
#
# ---
#
# ## 🔹 2. Contextos **Físicos (Cinemática)**
#
# Las ecuaciones de movimiento pueden ser no lineales.
#
# **Ejemplo 1 – Movimiento vertical con resistencia cuadrática**
# La ecuación para la posición en caída libre con resistencia del aire:
#
# $$
# y(t) = \frac{m}{k} \ln \left( \cosh \left( \sqrt{\frac{gk}{m}}\, t \right)\right)
# $$
#
# Si quiero determinar el tiempo $t$ en que el objeto alcanza una altura $y_0$, debo resolver:
#
# $$
# f(t) = \frac{m}{k} \ln \left( \cosh \left( \sqrt{\tfrac{gk}{m}}\, t \right)\right) - y_0 = 0
# $$
#
# Newton–Raphson es aplicable.
#
# **Ejemplo 2 – Alcance de un proyectil**
# La ecuación de alcance con fricción no tiene forma cerrada. Si se conoce $R$ y se quiere encontrar el ángulo $\theta$:
#
# $$
# R(\theta) = \frac{v_0^2}{g}\sin(2\theta) - \frac{k}{m} \theta^2
# $$
#
# Resolver $f(\theta) = R(\theta) - R_0 = 0$ requiere Newton–Raphson.
#
# ---
#
# ## 🔹 3. Contextos **Económicos**
#
# Las ecuaciones de equilibrio de mercados o de inversión suelen ser no lineales.
#
# **Ejemplo 1 – Tasa Interna de Retorno (TIR)**
# La TIR se obtiene resolviendo:
#
# $$
# f(r) = \sum_{t=0}^n \frac{C_t}{(1+r)^t} = 0
# $$
#
# donde $C_t$ son los flujos de caja.
# Como no hay fórmula cerrada para $r$, se aplica Newton–Raphson.
#
# **Ejemplo 2 – Modelo de oferta y demanda no lineal**
# Supongamos:
#
# $$
# Q_d(p) = a - b \ln(p), \quad Q_s(p) = c + dp^2
# $$
#
# El equilibrio se obtiene resolviendo:
#
# $$
# f(p) = a - b \ln(p) - (c + dp^2) = 0
# $$
#
# Newton–Raphson permite encontrar el precio de equilibrio $p^*$.
#
# ---
#
# ✅ Resumiendo:
#
# * **Agropecuario:** crecimiento logístico, producción óptima.
# * **Físico (cinemática):** caída libre con resistencia, proyectil con fricción.
# * **Económico:** TIR, equilibrio oferta-demanda no lineal.
#
# ---
#
# ¿Quieres que te prepare un **Jupyter Notebook con implementaciones en Python** de estos tres tipos de problemas (uno por área) para que lo uses con tus estudiantes?
